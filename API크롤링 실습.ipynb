# %%
import requests
import xmltodict # xml 데이터를 dictionary로 변환해줌
key = 'MIbCq7ZQGwZkz7xfyDuImI86N7oEPR2UDRPzHbZnYfENL94B8fhkJJLpDtb3b3DbPGvcQqHhiMfSl%2BvF3uU3yw%3D%3D'
decode_key = requests.utils.unquote(key)
xml_data = []
p_num = 1
while p_num < 5:
    response = requests.get('http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19SidoInfStateJson\
# ?serviceKey={}\
&numOfRows=10\
&pageNo={}\
&type=xml'.format(key,p_num))
    if p_num == 5:
        break
    xml_data2 = xmltodict.parse(response.text)
    p_num += 1
    print( xml_data)

# %%
# 가져온 xml 데이터를 dictionary 형태로 바꾸기(xmltodict 이용)
xml_data2 = xmltodict.parse(response.text)
xml_data2
# Out:
# OrderedDict([('response',
#               OrderedDict([('header',
#                             OrderedDict([('resultCode', '00'),
#                                          ('resultMsg', 'NORMAL SERVICE.')])),
#                            ('body',
#                             OrderedDict([('items',
#                                           OrderedDict([('item',
#                                                         [OrderedDict([('createDt',
#                                                                        '2022-01-07 09:07:38.476'),
#                                                                       ('deathCnt',
#                                                                        '16'),
#                                                                       ('defCnt',
#                                                                        '7031'),
#                                                                       ('gubun',
# ...

# %%
informations  = xml_data2['response']['body']['items']['item']

# %%
for info in informations:
    print(info['createDt'],  info['gubun'], info['localOccCnt'],info['deathCnt'], info['qurRate'], info['isolClearCnt'])
# Out:
# 2022-01-07 09:07:38.476 검역 0 16 - 6502
# 2022-01-07 09:07:38.476 제주 8 13 709 4549
# 2022-01-07 09:07:38.475 경남 99 102 650 19689
# 2022-01-07 09:07:38.475 경북 104 178 607 14426
# 2022-01-07 09:07:38.475 전남 120 40 354 5695
# 2022-01-07 09:07:38.475 전북 78 112 569 8920
# 2022-01-07 09:07:38.474 충남 108 156 892 16618
# 2022-01-07 09:07:38.474 충북 88 116 749 11063
# 2022-01-07 09:07:38.474 강원 88 108 836 11916
# 2022-01-07 09:07:38.474 경기 1224 1906 1439 156249
# 2022-01-07 09:07:38.474 세종 14 4 602 2074
# 2022-01-07 09:07:38.473 울산 33 63 639 6644
# 2022-01-07 09:07:38.473 대전 28 179 866 11051
# 2022-01-07 09:07:38.473 광주 87 49 597 7763
# 2022-01-07 09:07:38.473 인천 172 293 1299 33717
# 2022-01-07 09:07:38.472 대구 95 373 999 22193
# 2022-01-07 09:07:38.472 부산 204 311 791 23228
# 2022-01-07 09:07:38.472 서울 979 1913 2455 187191
# 2022-01-07 09:07:38.471 합계 3529 5932 1273 549488

# %%
#등록일시, 지역발생 수 , 사망자 수, 10만명당 발생률
for info in informations:
    print(info['createDt'],  info['gubun'], info['localOccCnt'],info['deathCnt'], info['qurRate'], info['isolClearCnt'])
# Out:
# 2022-01-07 09:07:38.476 검역 0 16 - 6502
# 2022-01-07 09:07:38.476 제주 8 13 709 4549
# 2022-01-07 09:07:38.475 경남 99 102 650 19689
# 2022-01-07 09:07:38.475 경북 104 178 607 14426
# 2022-01-07 09:07:38.475 전남 120 40 354 5695
# 2022-01-07 09:07:38.475 전북 78 112 569 8920
# 2022-01-07 09:07:38.474 충남 108 156 892 16618
# 2022-01-07 09:07:38.474 충북 88 116 749 11063
# 2022-01-07 09:07:38.474 강원 88 108 836 11916
# 2022-01-07 09:07:38.474 경기 1224 1906 1439 156249
# 2022-01-07 09:07:38.474 세종 14 4 602 2074
# 2022-01-07 09:07:38.473 울산 33 63 639 6644
# 2022-01-07 09:07:38.473 대전 28 179 866 11051
# 2022-01-07 09:07:38.473 광주 87 49 597 7763
# 2022-01-07 09:07:38.473 인천 172 293 1299 33717
# 2022-01-07 09:07:38.472 대구 95 373 999 22193
# 2022-01-07 09:07:38.472 부산 204 311 791 23228
# 2022-01-07 09:07:38.472 서울 979 1913 2455 187191
# 2022-01-07 09:07:38.471 합계 3529 5932 1273 549488

# %% [markdown]
# 1. 기획
# 크롤링 목적
#
# 인터넷에서 의류를 구매 시 사이즈를 한 눈에 알아보기 힘들다는 점이 있음
# 무신사에서는 사이즈의 크다 보통 작다를 그래프로 보여주지만
# 신체 사이즈별 그래프가 아닌 단순 고객들의 사이즈 구매를 그래프로 한것으로 보여
# 자신의 신체사이즈에 맞는 데이터를 한눈에 시각화를 해보고 싶었다.
#
# 각 구매자들의 키와 몸무게와 구매사이즈, 만족도를 크롤링하여
# 크롤링한 데이터를 전처리 과정을 거쳐 시각화를 해보려고 했다.
#
# 그와 같이 텍스트 시각화를 하기위해 konlpy를 이용
# 워드클라우드를 이용하여 텍스트 시각화까지 해보았다.

# %%
# 실기 제출할때 플라타함수, 라인차트 사용

# 평가기준
# 1. 기획
# 2. 크롤링 코드(셀레늄, request, bs4, 공공데이터 포탈 ) + 시각화
# 3. 데이터 전처리
# 4. 데이터 시각화 (pie, line, geo, bubble, keyword 등 차트 활용)
# 5. 데이터 저장

# %%
import pandas as pd  # 판다스 : 데이터분석 라이브러리
import numpy as np   # 넘파이 : 숫자, 행렬 데이터 라이브러리
import requests 
import re  # 정규표현식

from bs4 import BeautifulSoup    # html 데이터를 전처리
from selenium import webdriver   # 웹 브라우저 자동화
from selenium.webdriver.common.keys import Keys
import chromedriver_autoinstaller

import time    # 서버와 통신할 때 중간중간 시간 지연. 보통은 1초
from tqdm import tqdm_notebook   # for문 돌릴 때 진행상황을 %게이지로 알려준다.

# 워닝 무시
import warnings
warnings.filterwarnings('ignore')

# %%
# Step 1. 크롬 웹브라우저 실행
# pip install chromedriver_autoinstaller
chrome_path = chromedriver_autoinstaller.install()
driver = webdriver.Chrome(chrome_path)

# 사이트 주소는 네이버
driver.get('https:/www.musinsa.com')
time.sleep(2)  # 2초간 정지

# %%
# 검색어, 검색 기간 정의
query_txt = input('1.크롤링할 키워드는 무엇입니까?: ')

#검색창  텍스트 제거
element = driver.find_element_by_id("search_query")
element.clear()

# Step 2. 네이버 검색창에 "검색어" 검색
element.send_keys(query_txt)  # query_txt는 위에서 입력한 키워드
element.submit()
time.sleep(2)

# 첫번째 옷 클릭
CSS_tran=".img-block"                         
driver.find_element_by_css_selector(CSS_tran).click()   # 사진 클릭
time.sleep(2)
# Out:
# 1.크롤링할 키워드는 무엇입니까?: 마크곤잘레스 맨투맨

# %%
#팝업창 닫기 1
close1 = '.btn.btn-close'
driver.find_element_by_css_selector(close1).click()
time.sleep(2)
driver.execute_script("window.scrollTo(0, 8800)")
time.sleep(1)

# %%
#팝업창 닫기 2
close2 = '.Commonstyled__PreviewCloseButton-sc-1uivlpa-3.jOVdaf'
driver.find_element_by_css_selector(close2).click()

# %%
# 총 페이지 수 
page = driver.find_element_by_xpath('//*[@id="reviewListFragment"]/div[11]/div[1]')
page.text.split(' ')[0]
total = int(page.text.split(' ')[0])

# %%
size_in = driver.find_elements_by_css_selector(".review-goods-information__option-wrap")
 # 옷 사이즈 정보 
for size in size_in:
        cl_size = size.text
        size_info.append(cl_size[:1])
        cl_size

# %%
user_info = [] # 유저 정보 리스트
size_info = [] # 유저 구매 사이즈 리스트
review_info = []  # 사이즈 평 리스트
text_info = [] # 리뷰 글리스트
star_info = [] # 별점 리스트 
size_list = [] # 사이즈 크다 작다 딱 맞다 정보만 추출 

m = list(range(1,10))
for k in tqdm_notebook(list(map(str, m))):
    try :
    # 옷 사이즈 정보 
        size_in = driver.find_elements_by_css_selector(".review-goods-information__option-wrap")
    # 유저 정보 
        reviews = driver.find_elements_by_css_selector(".review-profile__body_information")
    # 사이즈 리뷰  
        size_re = driver.find_elements_by_css_selector('.review-evaluation__item')
    #텍스트 리스트
        text_li = driver.find_elements_by_css_selector('.review-contents__text')
    # 리뷰 별점(별 width %로 표시) 수집
        element = driver.find_elements_by_css_selector('.review-list__rating__active')
        
        # 유저 정보 
        for user in reviews:
            u_info = user.text
            user_info.append(u_info)
        # 옷 사이즈 정보 
        for size in size_in:
            cl_size = size.text
            size_info.append(cl_size[:1])
        # 사이즈 리뷰  
        for s_review in size_re:
            s_r = s_review.text
            review_info.append(s_r)
            
# 리뷰 별점 width로 수집 후, 5점 만점 숫자로 변환하기
        for i in range(len(element)):
            width = element[i].get_attribute('style')
        #print(width)
        # 숫자에 따라 별점으로 변환하기
            percent_star = int(re.findall('\d+', width)[0])
            percent_star = percent_star*0.05
            star_info.append(percent_star)
# 리뷰 글 
        for text in text_li:
            t_li = text.text
            text_info.append(t_li)
            
        if int(k) % 5 == 0: 
            driver.find_element_by_xpath('//*[@id="reviewListFragment"]/div[11]/div[2]/div/a[8]').click()
            
        driver.find_element_by_link_text(k).click()
        time.sleep(7)
        
    except:
        driver.find_element_by_link_text(k).click()
        time.sleep(7)

        
for i in review_info[::4]:
    size_list.append(i)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]

# %%
#사이즈 작다 크다 보통이다 리스트 
fit_list = []
for word in size_list:
    a = word.split('\n')
    fit_list.append(a[1])

# %%
df = pd.DataFrame({'user':user_info, 'size':size_info,'fit':fit_list,'star':star_info,'text':text_info})
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16388/358379934.py in <module>
# ----> 1 df = pd.DataFrame({'user':user_info, 'size':size_info,'fit':fit_list,'star':star_info,'text':text_info})
#       2 df
#
# C:\anacon\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# C:\anacon\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
#     465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#
# C:\anacon\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     117         # figure out the index, if necessary
#     118         if index is None:
# --> 119             index = _extract_index(arrays)
#     120         else:
#     121             index = ensure_index(index)
#
# C:\anacon\lib\site-packages\pandas\core\internals\construction.py in _extract_index(data)
#     633             lengths = list(set(raw_lengths))
#     634             if len(lengths) > 1:
# --> 635                 raise ValueError("All arrays must be of the same length")
#     636
#     637             if have_dicts:
#
# ValueError: All arrays must be of the same length

# %%
df
# Out:
#                user size    fit  star  \
# 0   남성, 178cm, 62kg    L     커요   4.0
# 1   여성, 165cm, 50kg    S  보통이에요   5.0
# 2   남성, 178cm, 60kg    M  보통이에요   5.0
# 3   남성, 182cm, 72kg    L  보통이에요   5.0
# 4   남성, 165cm, 80kg    X  보통이에요   5.0
# ..              ...  ...    ...   ...
# 85  남성, 170cm, 65kg    M  보통이에요   5.0
# 86  남성, 178cm, 67kg    L  보통이에요   5.0
# 87  남성, 174cm, 78kg    X  보통이에요   5.0
# 88  남성, 180cm, 73kg    L     커요   5.0
# 89  남성, 176cm, 86kg    L  보통이에요   5.0
#
#                                                  text
# 0   역시 마크 곤잘레스여서 그런지 확실히 예쁘긴 하네요...가격도 블랙 프라이데이때 사...
# 1                     커플티 맞췃는데 가격도 나쁘지않고 이쁘고 잘 맞고 좋네용
# 2   무난무난한 맨투맨입니다. 정사이즈로 샀는데 기장감이 딱 좋았어요. 편하게 입을 수 ...
# 3                   가성비갑~ 적당한 오버핏에 얇지도 두껍지도 않아서 너무좋아요
# 4                        엄청 편하고 데일리로 입기 좋아요! 거의 교복입니다
# ..                                                ...
# 85           너무 오버핏도 아니고 사이즈가 적당해서 너무 부해보이지도 않고 딱 좋아요
# 86         스몰로고가 포인트인 이 옷! 사이즈도 넉넉하고 딱 떨어지는 핏이라 이쁩니다~
# 87                잘 받았습니다 감사합니다\n딱 맞은 사이즈 세일해서 잘 샀습니다
# 88                    오버사이즈로 잘 나왓구요~ 편하게 입고 다니기에 좋습니다
# 89                          기본블랙 색깔이라서 심플하고 깔끔하니 좋습니다
#
# [90 rows x 5 columns]

# %%
# 5페이지 이후 페이지 넘겨보기 
m = list(range(2,total))
for k in list(map(str, m)):
    try :
        if int(k) % 5 == 0: 
            driver.find_element_by_xpath('//*[@id="reviewListFragment"]/div[11]/div[2]/div/a[8]').click()
            
        driver.find_element_by_link_text(k).click()
        time.sleep(2)
    except:
        driver.find_element_by_link_text(k).click()

# %%
df['gender'] = df['user'].str[:2] 
df['height'] = df['user'].str[4:9]
df['weight'] = df['user'].str[11:15]

# %%
df
# Out:
#                user size    fit  star  \
# 0   남성, 178cm, 62kg    L     커요   4.0
# 1   여성, 165cm, 50kg    S  보통이에요   5.0
# 2   남성, 178cm, 60kg    M  보통이에요   5.0
# 3   남성, 182cm, 72kg    L  보통이에요   5.0
# 4   남성, 165cm, 80kg    X  보통이에요   5.0
# ..              ...  ...    ...   ...
# 85  남성, 170cm, 65kg    M  보통이에요   5.0
# 86  남성, 178cm, 67kg    L  보통이에요   5.0
# 87  남성, 174cm, 78kg    X  보통이에요   5.0
# 88  남성, 180cm, 73kg    L     커요   5.0
# 89  남성, 176cm, 86kg    L  보통이에요   5.0
#
#                                                  text gender height weight
# 0   역시 마크 곤잘레스여서 그런지 확실히 예쁘긴 하네요...가격도 블랙 프라이데이때 사...     남성  178cm   62kg
# 1                     커플티 맞췃는데 가격도 나쁘지않고 이쁘고 잘 맞고 좋네용     여성  165cm   50kg
# 2   무난무난한 맨투맨입니다. 정사이즈로 샀는데 기장감이 딱 좋았어요. 편하게 입을 수 ...     남성  178cm   60kg
# 3                   가성비갑~ 적당한 오버핏에 얇지도 두껍지도 않아서 너무좋아요     남성  182cm   72kg
# 4                        엄청 편하고 데일리로 입기 좋아요! 거의 교복입니다     남성  165cm   80kg
# ..                                                ...    ...    ...    ...
# 85           너무 오버핏도 아니고 사이즈가 적당해서 너무 부해보이지도 않고 딱 좋아요     남성  170cm   65kg
# 86         스몰로고가 포인트인 이 옷! 사이즈도 넉넉하고 딱 떨어지는 핏이라 이쁩니다~     남성  178cm   67kg
# 87                잘 받았습니다 감사합니다\n딱 맞은 사이즈 세일해서 잘 샀습니다     남성  174cm   78kg
# 88                    오버사이즈로 잘 나왓구요~ 편하게 입고 다니기에 좋습니다     남성  180cm   73kg
# 89                          기본블랙 색깔이라서 심플하고 깔끔하니 좋습니다     남성  176cm   86kg
#
# [90 rows x 8 columns]

# %%
# 저장하기
df.to_csv("musinsa.csv",encoding = 'utf-8-sig')
# df.to_csv("blog_url.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10572/3670770484.py in <module>
#       1 # 저장하기
# ----> 2 df.to_csv("musinsa.csv",encoding = 'utf-8-sig')
#       3 # df.to_csv("blog_url.csv")
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt  # 시각화 라이브러리
import seaborn as sns            # 시각화 라이브러리
# import plotly      # interactive visualization library

# %%
musinsa= pd.read_csv('./musinsa.csv')
musinsa
# Out:
#     Unnamed: 0             user size    fit  star  \
# 0            0  남성, 178cm, 62kg    L     커요   4.0
# 1            1  여성, 165cm, 50kg    S  보통이에요   5.0
# 2            2  남성, 178cm, 60kg    M  보통이에요   5.0
# 3            3  남성, 182cm, 72kg    L  보통이에요   5.0
# 4            4  남성, 165cm, 80kg    X  보통이에요   5.0
# ..         ...              ...  ...    ...   ...
# 85          85  남성, 170cm, 65kg    M  보통이에요   5.0
# 86          86  남성, 178cm, 67kg    L  보통이에요   5.0
# 87          87  남성, 174cm, 78kg    X  보통이에요   5.0
# 88          88  남성, 180cm, 73kg    L     커요   5.0
# 89          89  남성, 176cm, 86kg    L  보통이에요   5.0
#
#                                                  text gender height weight
# 0   역시 마크 곤잘레스여서 그런지 확실히 예쁘긴 하네요...가격도 블랙 프라이데이때 사...     남성  178cm   62kg
# 1                     커플티 맞췃는데 가격도 나쁘지않고 이쁘고 잘 맞고 좋네용     여성  165cm   50kg
# 2   무난무난한 맨투맨입니다. 정사이즈로 샀는데 기장감이 딱 좋았어요. 편하게 입을 수 ...     남성  178cm   60kg
# 3                   가성비갑~ 적당한 오버핏에 얇지도 두껍지도 않아서 너무좋아요     남성  182cm   72kg
# 4                        엄청 편하고 데일리로 입기 좋아요! 거의 교복입니다     남성  165cm   80kg
# ..                                                ...    ...    ...    ...
# 85           너무 오버핏도 아니고 사이즈가 적당해서 너무 부해보이지도 않고 딱 좋아요     남성  170cm   65kg
# 86         스몰로고가 포인트인 이 옷! 사이즈도 넉넉하고 딱 떨어지는 핏이라 이쁩니다~     남성  178cm   67kg
# 87                잘 받았습니다 감사합니다\n딱 맞은 사이즈 세일해서 잘 샀습니다     남성  174cm   78kg
# 88                    오버사이즈로 잘 나왓구요~ 편하게 입고 다니기에 좋습니다     남성  180cm   73kg
# 89                          기본블랙 색깔이라서 심플하고 깔끔하니 좋습니다     남성  176cm   86kg
#
# [90 rows x 9 columns]

# %%
musinsa.loc[(musinsa['size'] == 'X'),'size'] = 'XL' 
musinsa
# Out:
#     Unnamed: 0             user size    fit  star  \
# 0            0  남성, 178cm, 62kg    L     커요   4.0
# 1            1  여성, 165cm, 50kg    S  보통이에요   5.0
# 2            2  남성, 178cm, 60kg    M  보통이에요   5.0
# 3            3  남성, 182cm, 72kg    L  보통이에요   5.0
# 4            4  남성, 165cm, 80kg   XL  보통이에요   5.0
# ..         ...              ...  ...    ...   ...
# 85          85  남성, 170cm, 65kg    M  보통이에요   5.0
# 86          86  남성, 178cm, 67kg    L  보통이에요   5.0
# 87          87  남성, 174cm, 78kg   XL  보통이에요   5.0
# 88          88  남성, 180cm, 73kg    L     커요   5.0
# 89          89  남성, 176cm, 86kg    L  보통이에요   5.0
#
#                                                  text gender height weight
# 0   역시 마크 곤잘레스여서 그런지 확실히 예쁘긴 하네요...가격도 블랙 프라이데이때 사...     남성  178cm   62kg
# 1                     커플티 맞췃는데 가격도 나쁘지않고 이쁘고 잘 맞고 좋네용     여성  165cm   50kg
# 2   무난무난한 맨투맨입니다. 정사이즈로 샀는데 기장감이 딱 좋았어요. 편하게 입을 수 ...     남성  178cm   60kg
# 3                   가성비갑~ 적당한 오버핏에 얇지도 두껍지도 않아서 너무좋아요     남성  182cm   72kg
# 4                        엄청 편하고 데일리로 입기 좋아요! 거의 교복입니다     남성  165cm   80kg
# ..                                                ...    ...    ...    ...
# 85           너무 오버핏도 아니고 사이즈가 적당해서 너무 부해보이지도 않고 딱 좋아요     남성  170cm   65kg
# 86         스몰로고가 포인트인 이 옷! 사이즈도 넉넉하고 딱 떨어지는 핏이라 이쁩니다~     남성  178cm   67kg
# 87                잘 받았습니다 감사합니다\n딱 맞은 사이즈 세일해서 잘 샀습니다     남성  174cm   78kg
# 88                    오버사이즈로 잘 나왓구요~ 편하게 입고 다니기에 좋습니다     남성  180cm   73kg
# 89                          기본블랙 색깔이라서 심플하고 깔끔하니 좋습니다     남성  176cm   86kg
#
# [90 rows x 9 columns]

# %%
Mans = musinsa[musinsa.gender=='남성']
Mans = Mans[['gender','height','weight','fit','size']]

#여성
Girls = musinsa[musinsa.gender=='여성']
Girls = Girls[['gender','height','weight','fit','size']]

# %%
Mans
# Out:
#    gender height weight    fit size
# 0      남성  178cm   62kg     커요    L
# 2      남성  178cm   60kg  보통이에요    M
# 3      남성  182cm   72kg  보통이에요    L
# 4      남성  165cm   80kg  보통이에요   XL
# 5      남성  170cm   65kg     커요    M
# ..    ...    ...    ...    ...  ...
# 85     남성  170cm   65kg  보통이에요    M
# 86     남성  178cm   67kg  보통이에요    L
# 87     남성  174cm   78kg  보통이에요   XL
# 88     남성  180cm   73kg     커요    L
# 89     남성  176cm   86kg  보통이에요    L
#
# [76 rows x 5 columns]

# %%
# 남녀 비율 
g_grup = musinsa.groupby('gender')
g_grup_sr = g_grup.size()

#한글 꺠짐 방지
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# 남녀 비율 표시 파이 차트 
g_grup_sr.plot(kind='pie',figsize=(7,5),autopct='%.1f%%',colors=['cadetblue','bisque'])
plt.title('남녀비율',size = 15)
plt.legend(g_grup_sr.index,loc='best')
plt.show()

# %%
musinsa.text
# Out:
# 0     역시 마크 곤잘레스여서 그런지 확실히 예쁘긴 하네요...가격도 블랙 프라이데이때 사...
# 1                       커플티 맞췃는데 가격도 나쁘지않고 이쁘고 잘 맞고 좋네용
# 2     무난무난한 맨투맨입니다. 정사이즈로 샀는데 기장감이 딱 좋았어요. 편하게 입을 수 ...
# 3                     가성비갑~ 적당한 오버핏에 얇지도 두껍지도 않아서 너무좋아요
# 4                          엄청 편하고 데일리로 입기 좋아요! 거의 교복입니다
#                             ...
# 85             너무 오버핏도 아니고 사이즈가 적당해서 너무 부해보이지도 않고 딱 좋아요
# 86           스몰로고가 포인트인 이 옷! 사이즈도 넉넉하고 딱 떨어지는 핏이라 이쁩니다~
# 87                  잘 받았습니다 감사합니다\n딱 맞은 사이즈 세일해서 잘 샀습니다
# 88                      오버사이즈로 잘 나왓구요~ 편하게 입고 다니기에 좋습니다
# 89                            기본블랙 색깔이라서 심플하고 깔끔하니 좋습니다
# Name: text, Length: 90, dtype: object

# %%
# 텍스트 값 리스트로 변환 
content_list = musinsa.text.values.tolist()

# %%
import scipy as sp

from konlpy.tag import Kkma       ; kkma = Kkma()
from konlpy.tag import Hannanum   ; hannanum = Hannanum()
from konlpy.tag import Okt        ; t = Okt()
from konlpy.tag import *
import pickle

# from sklearn.feature_extraction.text import CountVectorizer
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.linear_model import LogisticRegression
# from sklearn.pipeline import Pipeline
# from sklearn.metrics import accuracy_score
# from sklearn.model_selection import train_test_split

# 그래프
# %matplotlib inline
import os
import graphviz             
from sklearn.tree import export_graphviz

# matplotlib 그래프 한글폰트 깨질 때 대처(Mac & Window)
import matplotlib
from matplotlib import font_manager, rc
import platform

if platform.system() == 'Windows':
# 윈도우인 경우
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:    
# Mac 인 경우
    rc('font', family='AppleGothic')
    
# 그래프에서 마이너스 기호가 표시되도록 하는 설정
matplotlib.rcParams['axes.unicode_minus'] = False

import warnings  
warnings.filterwarnings('ignore')

# %%
import nltk
from konlpy.tag import Okt; t = Okt()

# %%
# 리스트 중 str 타입이 아닌 요소들(nan값)이 존재함을 확인
for i in content_list:
    if type(i) == float:
        i = str(i)
        print(i)
        
# str 타입이 아닌 요소들이 있으면 전부 str 타입으로 바꿔라!
for i in range(len(content_list)):
    if type(content_list[i]) != str:
        content_list[i] = str(content_list[i])

# %%
content_list
# Out:
# ['역시 마크 곤잘레스여서 그런지 확실히 예쁘긴 하네요...가격도 블랙 프라이데이때 사서 싸게 잘 샀구요\n마크 곤잘레스여서 맨투맨 가격이 이해가 되긴하지만 살짝 비싼감이 없지 않나해요.\n특히 흰티랑 궁합이 좋은 듯해요. 요즘 날씨에 안에 흰티 입고 이거 입고 밖에 나갈 수 있어요.\n어느정도 돈이 넉넉하신 분은 이걸 구매하는 것도 나쁘지 않을 선택이에요',
#  '커플티 맞췃는데 가격도 나쁘지않고 이쁘고 잘 맞고 좋네용',
#  '무난무난한 맨투맨입니다. 정사이즈로 샀는데 기장감이 딱 좋았어요. 편하게 입을 수 있어서 손이 자주 갑니다!',
#  '가성비갑~ 적당한 오버핏에 얇지도 두껍지도 않아서 너무좋아요',
#  '엄청 편하고 데일리로 입기 좋아요! 거의 교복입니다',
#  '오버핏으로 입기 좋습니다.\n너무 두껍거나 얇지도 않은 적당한 두께감도 마음에 듭니다.\n로고도 깔끔하고 이쁩니다.',
#  '얇아서 가을에 입기 좋고 무난무낭하게 입기 좋아요',
#  '마크곤잘레스 검정 맨투맨사고 레이어드 하기 좋아서 회색도 샀어요',
#  '똑같은 디자인 다른 색상으로 또 다시 마크곤잘레스 맨투맨을 재구매 했습니다.. 디자인이 너무 예뻐서 계속 사게 되네요!!',
#  '저희 동생인데 애가 조금 근육이 있다보니깐 옷핏이 잘서네요. 3대 600정도 침. 특히 어깨가 좁아서 딱 맞아요.',
#  '역시 마크 곤잘레스여서 그런지 확실히 예쁘긴 하네요...가격도 블랙 프라이데이때 사서 싸게 잘 샀구요\n마크 곤잘레스여서 맨투맨 가격이 이해가 되긴하지만 살짝 비싼감이 없지 않나해요.\n특히 흰티랑 궁합이 좋은 듯해요. 요즘 날씨에 안에 흰티 입고 이거 입고 밖에 나갈 수 있어요.\n어느정도 돈이 넉넉하신 분은 이걸 구매하는 것도 나쁘지 않을 선택이에요',
#  '커플티 맞췃는데 가격도 나쁘지않고 이쁘고 잘 맞고 좋네용',
#  '무난무난한 맨투맨입니다. 정사이즈로 샀는데 기장감이 딱 좋았어요. 편하게 입을 수 있어서 손이 자주 갑니다!',
#  '가성비갑~ 적당한 오버핏에 얇지도 두껍지도 않아서 너무좋아요',
#  '엄청 편하고 데일리로 입기 좋아요! 거의 교복입니다',
#  '오버핏으로 입기 좋습니다.\n너무 두껍거나 얇지도 않은 적당한 두께감도 마음에 듭니다.\n로고도 깔끔하고 이쁩니다.',
#  '얇아서 가을에 입기 좋고 무난무낭하게 입기 좋아요',
#  '마크곤잘레스 검정 맨투맨사고 레이어드 하기 좋아서 회색도 샀어요',
#  '똑같은 디자인 다른 색상으로 또 다시 마크곤잘레스 맨투맨을 재구매 했습니다.. 디자인이 너무 예뻐서 계속 사게 되네요!!',
#  '저희 동생인데 애가 조금 근육이 있다보니깐 옷핏이 잘서네요. 3대 600정도 침. 특히 어깨가 좁아서 딱 맞아요.',
#  '맨투맨 보단 후드를 많이 샀는데 맨투맨도 이쁘네요 역시군요',
#  '기모가 나쁘지는 않은데 애매함 총장이 좀 짧은편',
#  '믿고사는 마곤 블프때 마니 사서 잘입고 있어요~\n퀄리티 좋고 컬러 이쁘고 굿',
#  '예쁘고 편하고 활용도 높고 잘 입고 있습니다 굿굿',
#  '생각보단 크네요. 오버핏으로 입기에는 괜찮네요. 한 사이즈 다운해도 괜찮겠어요.',
#  '사진이랑 똑같고 사이즈도 맞는 것 같아요.배송도 빨라요.',
#  '검정색 구입한 후 만족해서 회색도 구입했는데 다 만족스럽네요',
#  '믿고 사는 마크곤잘레스 입니다 맨투맨 역시 이뻐요',
#  '착용하면 더 이쁘네요 두께감도 살짝?있고\n만족합니다',
#  '회색맨투맨이 없어서 구매했는데 만족스럽네용 제가 뱃살 개심한데 시보리 좀 올려입으면 뱃살 커버해줘요ㅋㅋ실측사이즈 보고 M샀는데 L샀으면 더 뚱뚱해보이고 핏도 이상했을거같아요 다행이에요.. 두께는 얇긴한데 안에 반팔도 겹쳐입어서 딱히 춥진않아요 봄가을에 입기 딱좋은거같아요!',
#  '팔길이, 전체길이 다 적당해서 이뻐요\n남여 구분없이 입을 수 있을 것 같아서 좋은 듯',
#  '검은색 맨투맨 고민할 필요가 있나여??\n마크 곤잘레스 원툴로 가야하는거 아닌가여?\n스몰로고가 너무 귀여워여!!',
#  '로고가 깔끔하게 들어가서 이뻐요 사이즈도 딱입니다',
#  '동생 주려고 구매했어요 딱 예쁘게 잘 맞아요 색깔이 예쁘네요',
#  '생각보단 살짝 크긴 한데 재질도 좋고 정말 편해요',
#  '무난무난한 검정맨투맨입니다 블프때 싸게 잘 샀네요',
#  '레이어드해서 입기 좋아요. 재질도 좋고 세탁 후 변형도 없어요.\n강추합니다.',
#  '블랙프라이데이 세일로 저렴하게 구매했구 별 기대 안 했는데 핏도 예쁘고 넘 좋습니당',
#  '마크곤잘레스가 교복인가봐요..\n아드님 사드렸더니 좋아해요',
#  '완전 편하고 부드러워서 자주 입고 다녀요 아주 좋습니다',
#  '진짜 좋음 예쁘고 딱 좋아요 여러분 다 사는걸 추천함 가격대비도 나쁘지않아요',
#  '정말 편하고 핏감도 좋네요. 마크 곤잘레스 느낌 살아요 짱짱',
#  '할인한 김에 샀는데 핏도 좋고 두께도 좋고 적당히 입을것 같습니다',
#  '딱 좋습니다 안감도 좋고 재질도 좋아요 만족합니다',
#  '소재좋고 배송빠르고\n핏도 넘 예뻐요.만족해요.\n뒷로고도 예뻐요~',
#  '사이즈가 딱맞아서 정사이즈를 구매하시는것을 추천드립니다',
#  '딱 정 핏이구요 177에 70 중 후반\n핏감 되게 좋게 나왔어요 롯데마트가서 사는 11자핏\n그런 핏이아니라 어깨 살짝 넘어가는 그런핏\n어깡들은 타이트할수있는 그런핏\n오버핏 좋아하시면 xL 추천\n재질은 부드럽고 낫배드 함\n바닥에 놔두면 먼지묻음\n좋고 무난한 옷',
#  '오버핏 느낌이 생각보다 심해요, 단정하게 딱가려면 한치수 작게 사는것도 괜찮을거 같습니다.\n색감은 괜찮아서 가을에 입기 좋은거 같아요.',
#  '사이즈 너무좋네요\n스타일은 기본스타일이라 두루두루 매치하기 좋습니다',
#  '너무 예뻐요 ㅠㅠ핏도 맘에들고 편하게 입을 수 있어영! 팔목 시보리 짱짱한거 넘 조아여 ㅋㅋ',
#  '옷 깔끔하고 좋아요 길이도 적당하고 다른 옷들이랑 입어도 무난해요',
#  '사이즈 색상 너무 완벽합니다 참고하시면 좋아요!',
#  '편하게 입기 좋고 핏도 잘 맞아서 정말 맘에 들어요',
#  '로고가 너무 작어서 안 보이지만… 진짜 예뻐여 심플하구ㅠㅠ 검은색 맨투맨 브랜드꺼 급필이었는데 희희 편하게 입고 다닐게용',
#  '옷 이쁜데 사진 찍느라 실루엣이 잘안나왔네요ㅜ 이쁘고 실루엣도 좋고 색감도 괜찮아요ㅎㅎ',
#  '심플한맨투맨입니다. 마크곤잘레스영어마크맘에들어요',
#  '사촌동생 사줬는데 너무 잘입고 있어요~~큰편이고 좋아요…!',
#  '어디에나 잘 어울리고 편해서 후회하지 않을 것 같아요',
#  '옷 핏도 딱 맞고 스타일도 이쁩니다! 앞으로도 자주 입을꺼 같아요!',
#  '디자인 무난하고 좋아요\n재질은 뻣뻣하지 않고 부들부들해요\n색감도 너무 쨍하지 않게 무난하니 잘 빠졌어요\n로고가포인트 줘서 이뻐요\n사이즈는 덩치 있으시면 좀 껴요\n슬림하신분들 걸치는 느낌으로 입으시면 좋을듯해요',
#  '옷 깔끔하고 좋아요 길이도 적당하고 다른 옷들이랑 입어도 무난해요',
#  '사이즈 색상 너무 완벽합니다 참고하시면 좋아요!',
#  '편하게 입기 좋고 핏도 잘 맞아서 정말 맘에 들어요',
#  '로고가 너무 작어서 안 보이지만… 진짜 예뻐여 심플하구ㅠㅠ 검은색 맨투맨 브랜드꺼 급필이었는데 희희 편하게 입고 다닐게용',
#  '옷 이쁜데 사진 찍느라 실루엣이 잘안나왔네요ㅜ 이쁘고 실루엣도 좋고 색감도 괜찮아요ㅎㅎ',
#  '심플한맨투맨입니다. 마크곤잘레스영어마크맘에들어요',
#  '사촌동생 사줬는데 너무 잘입고 있어요~~큰편이고 좋아요…!',
#  '어디에나 잘 어울리고 편해서 후회하지 않을 것 같아요',
#  '옷 핏도 딱 맞고 스타일도 이쁩니다! 앞으로도 자주 입을꺼 같아요!',
#  '디자인 무난하고 좋아요\n재질은 뻣뻣하지 않고 부들부들해요\n색감도 너무 쨍하지 않게 무난하니 잘 빠졌어요\n로고가포인트 줘서 이뻐요\n사이즈는 덩치 있으시면 좀 껴요\n슬림하신분들 걸치는 느낌으로 입으시면 좋을듯해요',
#  '사이즈 넉넉하고 좋네요\n운동할 때 애용할거같습니다',
#  '스몰로고가 좋아서 샀는데 실물이 더 괜찮네요! 오버핏이라서 알아두셔야 할 거 같아요',
#  '생각보다 사이즈가 크네여! 기장도 길고 맘에들어요~',
#  '시보리가 매우 짱짱해서 걷어서 입기 좋구요 이쁩니다',
#  '너무 두껍지도 얇지도 않아요! 가을에 입으면 딱 좋고 겨울에 패딩 안에 입기도 좋아용 가볍게 입기 좋습니다~(아이고 검은 옷을 입으니까 거울 얼룩덜룩 하네요...옷은 깨끗합니다 ㅎ)',
#  '옷을 크게 삿는데 그래도 딱 적당하고 좋은가 같아요!',
#  '맨투맨 너무 이뻐요 어디에도 찰떡 기본템으로 너무 좋네요!',
#  '앞에는 스몰 뒤에는 빅로고가 너무 맘에 들어요 이뻐욤',
#  '옷이 편해서 입고다니기 좋고 색감도 괜찮아서 맘에들어요',
#  '청바지에도 잘 어울리는 마크 곤잘레스\n무슨 스타일이든 잘 소화될 것 같아요',
#  '로고가 작은게 아주 매력이네요\n눈에 띄지는 않지만 너무 이뻐요',
#  '역시 마크곤잘레스.. 명성값 하는거 같아요\n색감좋고 깔끔 그 자체로 너무 이쁘네요',
#  '약간 오버핏 같기도 해요.\n오랜만에 옷을 사서 그런지 오버핏이 유행같기도해요. 내가 너무 옛날사람이라서 그런거 같기도 해요. 암튼 맘에 쏘옥 들어요. 사이즈도 보다보니까 맞는거 같아요.',
#  '블프기간에 싸게 잘산거 같습니다 배송이 오래 걸렷지만 이쁘네요',
#  '색감이 좋아서 마음에 듭니다. 회색 옷 찾으시는 분들께 추천드려요.',
#  '너무 오버핏도 아니고 사이즈가 적당해서 너무 부해보이지도 않고 딱 좋아요',
#  '스몰로고가 포인트인 이 옷! 사이즈도 넉넉하고 딱 떨어지는 핏이라 이쁩니다~',
#  '잘 받았습니다 감사합니다\n딱 맞은 사이즈 세일해서 잘 샀습니다',
#  '오버사이즈로 잘 나왓구요~ 편하게 입고 다니기에 좋습니다',
#  '기본블랙 색깔이라서 심플하고 깔끔하니 좋습니다']

# %%
# 수집한 글들을 한 문장으로 합치기
content_text = ''

for each_line in content_list[:2000]:
    content_text = content_text + each_line + '\n'

content_text
# Out:
# '역시 마크 곤잘레스여서 그런지 확실히 예쁘긴 하네요...가격도 블랙 프라이데이때 사서 싸게 잘 샀구요\n마크 곤잘레스여서 맨투맨 가격이 이해가 되긴하지만 살짝 비싼감이 없지 않나해요.\n특히 흰티랑 궁합이 좋은 듯해요. 요즘 날씨에 안에 흰티 입고 이거 입고 밖에 나갈 수 있어요.\n어느정도 돈이 넉넉하신 분은 이걸 구매하는 것도 나쁘지 않을 선택이에요\n커플티 맞췃는데 가격도 나쁘지않고 이쁘고 잘 맞고 좋네용\n무난무난한 맨투맨입니다. 정사이즈로 샀는데 기장감이 딱 좋았어요. 편하게 입을 수 있어서 손이 자주 갑니다!\n가성비갑~ 적당한 오버핏에 얇지도 두껍지도 않아서 너무좋아요\n엄청 편하고 데일리로 입기 좋아요! 거의 교복입니다\n오버핏으로 입기 좋습니다.\n너무 두껍거나 얇지도 않은 적당한 두께감도 마음에 듭니다.\n로고도 깔끔하고 이쁩니다.\n얇아서 가을에 입기 좋고 무난무낭하게 입기 좋아요\n마크곤잘레스 검정 맨투맨사고 레이어드 하기 좋아서 회색도 샀어요\n똑같은 디자인 다른 색상으로 또 다시 마크곤잘레스 맨투맨을 재구매 했습니다.. 디자인이 너무 예뻐서 계속 사게 되네요!!\n저희 동생인데 애가 조금 근육이 있다보니깐 옷핏이 잘서네요. 3대 600정도 침. 특히 어깨가 좁아서 딱 맞아요.\n역시 마크 곤잘레스여서 그런지 확실히 예쁘긴 하네요...가격도 블랙 프라이데이때 사서 싸게 잘 샀구요\n마크 곤잘레스여서 맨투맨 가격이 이해가 되긴하지만 살짝 비싼감이 없지 않나해요.\n특히 흰티랑 궁합이 좋은 듯해요. 요즘 날씨에 안에 흰티 입고 이거 입고 밖에 나갈 수 있어요.\n어느정도 돈이 넉넉하신 분은 이걸 구매하는 것도 나쁘지 않을 선택이에요\n커플티 맞췃는데 가격도 나쁘지않고 이쁘고 잘 맞고 좋네용\n무난무난한 맨투맨입니다. 정사이즈로 샀는데 기장감이 딱 좋았어요. 편하게 입을 수 있어서 손이 자주 갑니다!\n가성비갑~ 적당한 오버핏에 얇지도 두껍지도 않아서 너무좋아요\n엄청 편하고 데일리로 입기 좋아요! 거의 교복입니다\n오버핏으로 입기 좋습니다.\n너무 두껍거나 얇지도 않은 적당한 두께감도 마음에 듭니다.\n로고도 깔끔하고 이쁩니다.\n얇아서 가을에 입기 좋고 무난무낭하게 입기 좋아요\n마크곤잘레스 검정 맨투맨사고 레이어드 하기 좋아서 회색도 샀어요\n똑같은 디자인 다른 색상으로 또 다시 마크곤잘레스 맨투맨을 재구매 했습니다.. 디자인이 너무 예뻐서 계속 사게 되네요!!\n저희 동생인데 애가 조금 근육이 있다보니깐 옷핏이 잘서네요. 3대 600정도 침. 특히 어깨가 좁아서 딱 맞아요.\n맨투맨 보단 후드를 많이 샀는데 맨투맨도 이쁘네요 역시군요\n기모가 나쁘지는 않은데 애매함 총장이 좀 짧은편\n믿고사는 마곤 블프때 마니 사서 잘입고 있어요~\n퀄리티 좋고 컬러 이쁘고 굿\n예쁘고 편하고 활용도 높고 잘 입고 있습니다 굿굿\n생각보단 크네요. 오버핏으로 입기에는 괜찮네요. 한 사이즈 다운해도 괜찮겠어요.\n사진이랑 똑같고 사이즈도 맞는 것 같아요.배송도 빨라요.\n검정색 구입한 후 만족해서 회색도 구입했는데 다 만족스럽네요\n믿고 사는 마크곤잘레스 입니다 맨투맨 역시 이뻐요\n착용하면 더 이쁘네요 두께감도 살짝?있고\n만족합니다\n회색맨투맨이 없어서 구매했는데 만족스럽네용 제가 뱃살 개심한데 시보리 좀 올려입으면 뱃살 커버해줘요ㅋㅋ실측사이즈 보고 M샀는데 L샀으면 더 뚱뚱해보이고 핏도 이상했을거같아요 다행이에요.. 두께는 얇긴한데 안에 반팔도 겹쳐입어서 딱히 춥진않아요 봄가을에 입기 딱좋은거같아요!\n팔길이, 전체길이 다 적당해서 이뻐요\n남여 구분없이 입을 수 있을 것 같아서 좋은 듯\n검은색 맨투맨 고민할 필요가 있나여??\n마크 곤잘레스 원툴로 가야하는거 아닌가여?\n스몰로고가 너무 귀여워여!!\n로고가 깔끔하게 들어가서 이뻐요 사이즈도 딱입니다\n동생 주려고 구매했어요 딱 예쁘게 잘 맞아요 색깔이 예쁘네요\n생각보단 살짝 크긴 한데 재질도 좋고 정말 편해요\n무난무난한 검정맨투맨입니다 블프때 싸게 잘 샀네요\n레이어드해서 입기 좋아요. 재질도 좋고 세탁 후 변형도 없어요.\n강추합니다.\n블랙프라이데이 세일로 저렴하게 구매했구 별 기대 안 했는데 핏도 예쁘고 넘 좋습니당\n마크곤잘레스가 교복인가봐요..\n아드님 사드렸더니 좋아해요\n완전 편하고 부드러워서 자주 입고 다녀요 아주 좋습니다\n진짜 좋음 예쁘고 딱 좋아요 여러분 다 사는걸 추천함 가격대비도 나쁘지않아요\n정말 편하고 핏감도 좋네요. 마크 곤잘레스 느낌 살아요 짱짱\n할인한 김에 샀는데 핏도 좋고 두께도 좋고 적당히 입을것 같습니다\n딱 좋습니다 안감도 좋고 재질도 좋아요 만족합니다\n소재좋고 배송빠르고\n핏도 넘 예뻐요.만족해요.\n뒷로고도 예뻐요~\n사이즈가 딱맞아서 정사이즈를 구매하시는것을 추천드립니다\n딱 정 핏이구요 177에 70 중 후반\n핏감 되게 좋게 나왔어요 롯데마트가서 사는 11자핏\n그런 핏이아니라 어깨 살짝 넘어가는 그런핏\n어깡들은 타이트할수있는 그런핏\n오버핏 좋아하시면 xL 추천\n재질은 부드럽고 낫배드 함\n바닥에 놔두면 먼지묻음\n좋고 무난한 옷\n오버핏 느낌이 생각보다 심해요, 단정하게 딱가려면 한치수 작게 사는것도 괜찮을거 같습니다.\n색감은 괜찮아서 가을에 입기 좋은거 같아요.\n사이즈 너무좋네요\n스타일은 기본스타일이라 두루두루 매치하기 좋습니다\n너무 예뻐요 ㅠㅠ핏도 맘에들고 편하게 입을 수 있어영! 팔목 시보리 짱짱한거 넘 조아여 ㅋㅋ\n옷 깔끔하고 좋아요 길이도 적당하고 다른 옷들이랑 입어도 무난해요\n사이즈 색상 너무 완벽합니다 참고하시면 좋아요!\n편하게 입기 좋고 핏도 잘 맞아서 정말 맘에 들어요\n로고가 너무 작어서 안 보이지만… 진짜 예뻐여 심플하구ㅠㅠ 검은색 맨투맨 브랜드꺼 급필이었는데 희희 편하게 입고 다닐게용\n옷 이쁜데 사진 찍느라 실루엣이 잘안나왔네요ㅜ 이쁘고 실루엣도 좋고 색감도 괜찮아요ㅎㅎ\n심플한맨투맨입니다. 마크곤잘레스영어마크맘에들어요\n사촌동생 사줬는데 너무 잘입고 있어요~~큰편이고 좋아요…!\n어디에나 잘 어울리고 편해서 후회하지 않을 것 같아요\n옷 핏도 딱 맞고 스타일도 이쁩니다! 앞으로도 자주 입을꺼 같아요!\n디자인 무난하고 좋아요\n재질은 뻣뻣하지 않고 부들부들해요\n색감도 너무 쨍하지 않게 무난하니 잘 빠졌어요\n로고가포인트 줘서 이뻐요\n사이즈는 덩치 있으시면 좀 껴요\n슬림하신분들 걸치는 느낌으로 입으시면 좋을듯해요\n옷 깔끔하고 좋아요 길이도 적당하고 다른 옷들이랑 입어도 무난해요\n사이즈 색상 너무 완벽합니다 참고하시면 좋아요!\n편하게 입기 좋고 핏도 잘 맞아서 정말 맘에 들어요\n로고가 너무 작어서 안 보이지만… 진짜 예뻐여 심플하구ㅠㅠ 검은색 맨투맨 브랜드꺼 급필이었는데 희희 편하게 입고 다닐게용\n옷 이쁜데 사진 찍느라 실루엣이 잘안나왔네요ㅜ 이쁘고 실루엣도 좋고 색감도 괜찮아요ㅎㅎ\n심플한맨투맨입니다. 마크곤잘레스영어마크맘에들어요\n사촌동생 사줬는데 너무 잘입고 있어요~~큰편이고 좋아요…!\n어디에나 잘 어울리고 편해서 후회하지 않을 것 같아요\n옷 핏도 딱 맞고 스타일도 이쁩니다! 앞으로도 자주 입을꺼 같아요!\n디자인 무난하고 좋아요\n재질은 뻣뻣하지 않고 부들부들해요\n색감도 너무 쨍하지 않게 무난하니 잘 빠졌어요\n로고가포인트 줘서 이뻐요\n사이즈는 덩치 있으시면 좀 껴요\n슬림하신분들 걸치는 느낌으로 입으시면 좋을듯해요\n사이즈 넉넉하고 좋네요\n운동할 때 애용할거같습니다\n스몰로고가 좋아서 샀는데 실물이 더 괜찮네요! 오버핏이라서 알아두셔야 할 거 같아요\n생각보다 사이즈가 크네여! 기장도 길고 맘에들어요~\n시보리가 매우 짱짱해서 걷어서 입기 좋구요 이쁩니다\n너무 두껍지도 얇지도 않아요! 가을에 입으면 딱 좋고 겨울에 패딩 안에 입기도 좋아용 가볍게 입기 좋습니다~(아이고 검은 옷을 입으니까 거울 얼룩덜룩 하네요...옷은 깨끗합니다 ㅎ)\n옷을 크게 삿는데 그래도 딱 적당하고 좋은가 같아요!\n맨투맨 너무 이뻐요 어디에도 찰떡 기본템으로 너무 좋네요!\n앞에는 스몰 뒤에는 빅로고가 너무 맘에 들어요 이뻐욤\n옷이 편해서 입고다니기 좋고 색감도 괜찮아서 맘에들어요\n청바지에도 잘 어울리는 마크 곤잘레스\n무슨 스타일이든 잘 소화될  ...

# %%
tokens_ko = t.morphs(content_text)
tokens_ko
# Out:
# ['역시',
#  '마크',
#  '곤잘레스',
#  '여서',
#  '그런지',
#  '확실히',
#  '예쁘긴',
#  '하네요',
#  '...',
#  '가격',
#  '도',
#  '블랙',
#  '프라이데이',
#  '때',
#  '사서',
#  '싸게',
#  '잘',
#  '샀구요',
#  '\n',
#  '마크',
#  '곤잘레스',
#  '여서',
#  '맨',
#  '투맨',
#  '가격',
#  '이',
#  '이해',
#  '가',
#  '되긴',
#  '하지만',
#  '살짝',
#  '비싼',
#  '감',
#  '이',
#  '없지',
#  '않나',
#  '해',
#  '요',
#  '.',
#  '\n',
#  '특히',
#  '흰',
#  '티',
#  '랑',
#  '궁합',
#  '이',
#  '좋은',
#  '듯',
#  '해요',
#  '.',
#  '요즘',
#  '날씨',
#  '에',
#  '안',
#  '에',
#  '흰',
#  '티',
#  '입고',
#  '이',
#  '거',
#  '입고',
#  '밖에',
#  '나갈',
#  '수',
#  '있어요',
#  '.',
#  '\n',
#  '어느',
#  '정도',
#  '돈',
#  '이',
#  '넉넉하신',
#  '분',
#  '은',
#  '이',
#  '걸',
#  '구매',
#  '하는',
#  '것',
#  '도',
#  '나쁘지',
#  '않을',
#  '선택',
#  '이에요',
#  '\n',
#  '커플티',
#  '맞췃는데',
#  '가격',
#  '도',
#  '나쁘지',
#  '않고',
#  '이쁘고',
#  '잘',
#  '맞고',
#  '좋',
#  '네',
#  '용',
#  '\n',
#  '무난',
#  '무난',
#  '한',
#  '맨',
#  '투',
#  '맨입',
#  '니',
#  '다',
#  '.',
#  '정사',
#  '이즈',
#  '로',
#  '샀는데',
#  '기장',
#  '감',
#  '이',
#  '딱',
#  '좋았어요',
#  '.',
#  '편하게',
#  '입',
#  '을',
#  '수',
#  '있어서',
#  '손',
#  '이',
#  '자주',
#  '갑니다',
#  '!',
#  '\n',
#  '가성',
#  '비갑',
#  '~',
#  '적당한',
#  '오',
#  '버핏',
#  '에',
#  '얇지도',
#  '두껍지도',
#  '않아서',
#  '너무',
#  '좋아요',
#  '\n',
#  '엄청',
#  '편하고',
#  '데',
#  '일리',
#  '로',
#  '입기',
#  '좋아요',
#  '!',
#  '거의',
#  '교복',
#  '입니다',
#  '\n',
#  '오',
#  '버핏',
#  '으로',
#  '입기',
#  '좋습니다',
#  '.',
#  '\n',
#  '너무',
#  '두껍거나',
#  '얇지도',
#  '않은',
#  '적당한',
#  '두께',
#  '감도',
#  '마음',
#  '에',
#  '듭니',
#  '다',
#  '.',
#  '\n',
#  '로고',
#  '도',
#  '깔끔하고',
#  '이쁩니다',
#  '.',
#  '\n',
#  '얇아서',
#  '가을',
#  '에',
#  '입기',
#  '좋고',
#  '무난',
#  '무낭',
#  '하',
#  '게',
#  '입기',
#  '좋아요',
#  '\n',
#  '마크',
#  '곤잘레스',
#  '검정',
#  '맨',
#  '투',
#  '맨',
#  '사고',
#  '레이어',
#  '드',
#  '하기',
#  '좋아서',
#  '회색',
#  '도',
#  '샀어요',
#  '\n',
#  '똑같은',
#  '디자인',
#  '다른',
#  '색상',
#  '으로',
#  '또',
#  '다시',
#  '마크',
#  '곤잘레스',
#  '맨',
#  '투맨',
#  '을',
#  '재구매',
#  '했습니다',
#  '..',
#  '디자인',
#  '이',
#  '너무',
#  '예뻐서',
#  '계속',
#  '사게',
#  '되네요',
#  '!!',
#  '\n',
#  '저희',
#  '동생',
#  '인데',
#  '애가',
#  '조금',
#  '근육',
#  '이',
#  '있다',
#  '보',
#  '니깐',
#  '옷핏',
#  '이',
#  '잘',
#  '서네요',
#  '.',
#  '3',
#  '대',
#  '600',
#  '정도',
#  '침',
#  '.',
#  '특히',
#  '어깨',
#  '가',
#  '좁아서',
#  '딱',
#  '맞아요',
#  '.',
#  '\n',
#  '역시',
#  '마크',
#  '곤잘레스',
#  '여서',
#  '그런지',
#  '확실히',
#  '예쁘긴',
#  '하네요',
#  '...',
#  '가격',
#  '도',
#  '블랙',
#  '프라이데이',
#  '때',
#  '사서',
#  '싸게',
#  '잘',
#  '샀구요',
#  '\n',
#  '마크',
#  '곤잘레스',
#  '여서',
#  '맨',
#  '투맨',
#  '가격',
#  '이',
#  '이해',
#  '가',
#  '되긴',
#  '하지만',
#  '살짝',
#  '비싼',
#  '감',
#  '이',
#  '없지',
#  '않나',
#  '해',
#  '요',
#  '.',
#  '\n',
#  '특히',
#  '흰',
#  '티',
#  '랑',
#  '궁합',
#  '이',
#  '좋은',
#  '듯',
#  '해요',
#  '.',
#  '요즘',
#  '날씨',
#  '에',
#  '안',
#  '에',
#  '흰',
#  '티',
#  '입고',
#  '이',
#  '거',
#  '입고',
#  '밖에',
#  '나갈',
#  '수',
#  '있어요',
#  '.',
#  '\n',
#  '어느',
#  '정도',
#  '돈',
#  '이',
#  '넉넉하신',
#  '분',
#  '은',
#  '이',
#  '걸',
#  '구매',
#  '하는',
#  '것',
#  '도',
#  '나쁘지',
#  '않을',
#  '선택',
#  '이에요',
#  '\n',
#  '커플티',
#  '맞췃는데',
#  '가격',
#  '도',
#  '나쁘지',
#  '않고',
#  '이쁘고',
#  '잘',
#  '맞고',
#  '좋',
#  '네',
#  '용',
#  '\n',
#  '무난',
#  '무난',
#  '한',
#  '맨',
#  '투',
#  '맨입',
#  '니',
#  '다',
#  '.',
#  '정사',
#  '이즈',
#  '로',
#  '샀는데',
#  '기장',
#  '감',
#  '이',
#  '딱',
#  '좋았어요',
#  '.',
#  '편하게',
#  '입',
#  '을',
#  '수',
#  '있어서',
#  '손',
#  '이',
#  '자주',
#  '갑니다',
#  '!',
#  '\n',
#  '가성',
#  '비갑',
#  '~',
#  '적당한',
#  '오',
#  '버핏',
#  '에',
#  '얇지도',
#  '두껍지도',
#  '않아서',
#  '너무',
#  '좋아요',
#  '\n',
#  '엄청',
#  '편하고',
#  '데',
#  '일리',
#  '로',
#  '입기',
#  '좋아요',
#  '!',
#  '거의',
#  '교복',
#  '입니다',
#  '\n',
#  '오',
#  '버핏',
#  '으로',
#  '입기',
#  '좋습니다',
#  '.',
#  '\n',
#  '너무',
#  '두껍거나',
#  '얇지도',
#  '않은',
#  '적당한',
#  '두께',
#  '감도',
#  '마음',
#  '에',
#  '듭니',
#  '다',
#  '.',
#  '\n',
#  '로고',
#  '도',
#  '깔끔하고',
#  '이쁩니다',
#  '.',
#  '\n',
#  '얇아서',
#  '가을',
#  '에',
#  '입기',
#  '좋고',
#  '무난',
#  '무낭',
#  '하',
#  '게',
#  '입기',
#  '좋아요',
#  '\n',
#  '마크',
#  '곤잘레스',
#  '검정',
#  '맨',
#  '투',
#  '맨',
#  '사고',
#  '레이어',
#  '드',
#  '하기',
#  '좋아서',
#  '회색',
#  '도',
#  '샀어요',
#  '\n',
#  '똑같은',
#  '디자인',
#  '다른',
#  '색상',
#  '으로',
#  '또',
#  '다시',
#  '마크',
#  '곤잘레스',
#  '맨',
#  '투맨',
#  '을',
#  '재구매',
#  '했습니다',
#  '..',
#  '디자인',
#  '이',
#  '너무',
#  '예뻐서',
#  '계속',
#  '사게',
#  '되네요',
#  '!!',
#  '\n',
#  '저희',
#  '동생',
#  '인데',
#  '애가',
#  '조금',
#  '근육',
#  '이',
#  '있다',
#  '보',
#  '니깐',
#  '옷핏',
#  '이',
#  '잘',
#  '서네요',
#  '.',
#  '3',
#  '대',
#  '600',
#  '정도',
#  '침',
#  '.',
#  '특히',
#  '어깨',
#  '가',
#  '좁아서',
#  '딱',
#  '맞아요',
#  '.',
#  '\n',
#  '맨',
#  '투맨',
#  '보단',
#  '후드',
#  '를',
#  '많이',
#  '샀는데',
#  '맨',
#  '투맨',
#  '도',
#  '이쁘네요',
#  '역시군요',
#  '\n',
#  '기모',
#  '가',
#  '나쁘지는',
#  '않은데',
#  '애매함',
#  '총장',
#  '이',
#  '좀',
#  '짧은',
#  '편',
#  '\n',
#  '믿고',
#  '사는',
#  '마곤',
#  '블프때',
#  '마니',
#  '사서',
#  '잘',
#  '입고',
#  '있어요',
#  '~',
#  '\n',
#  '퀄리티',
#  '좋고',
#  '컬러',
#  '이쁘고',
#  '굿',
#  '\n',
#  '예쁘고',
#  '편하고',
#  '활용',
#  '도',
#  '높고',
#  '잘',
#  '입고',
#  '있습니다',
#  '굿굿',
#  '\n',
#  '생각',
#  '보단',
#  '크네요',
#  '.',
#  '오',
#  '버핏',
#  '으로',
#  '입기에는',
#  '괜찮네요',
#  '.',
#  '한',
#  '사이즈',
#  '다운',
#  '해도',
#  '괜찮겠어요',
#  '.',
#  '\n',
#  '사진',
#  '이랑',
#  '똑같고',
#  '사이즈',
#  '도',
#  '맞는',
#  '것',
#  '같아요',
#  '.',
#  '배송',
#  '도',
#  '빨라요',
#  '.',
#  '\n',
#  '검정색',
#  '구입',
#  '한',
#  '후',
#  '만족해서',
#  '회색',
#  '도',
#  '구입',
#  '했는데',
#  '다',
#  '만족스럽네요',
#  '\n',
#  '믿고',
#  '사는',
#  '마크',
#  '곤잘레스',
#  '입니다',
#  '맨',
#  '투맨',
#  '역시',
#  '이뻐요',
#  '\n',
#  '착용',
#  '하면',
#  '더',
#  '이쁘네요',
#  '두께',
#  '감도',
#  '살짝',
#  '?',
#  '있고',
#  '\n',
#  '만족합니다',
#  '\n',
#  '회색',
#  '맨',
#  '투맨',
#  '이',
#  '없어서',
#  '구매',
#  '했는데',
#  '만족스럽',
#  '네',
#  '용',
#  '제',
#  '가',
#  '뱃살',
#  '개심',
#  '한',
#  '데',
#  '시',
#  '보리',
#  '좀',
#  '올려',
#  '입으면',
#  '뱃살',
#  '커버',
#  '해줘요',
#  'ㅋㅋ',
#  '실',
#  '측',
#  '사이즈',
#  '보고',
#  'M',
#  '샀는데',
#  'L',
#  '샀으면',
#  '더',
#  '뚱뚱해',
#  '보이',
#  '고',
#  '핏',
#  '도',
#  '이상했을거',
#  '같아요',
#  '다행',
#  '이에요',
#  '..',
#  '두께',
#  '는',
#  '얇긴한데',
#  '안',
#  '에',
#  '반',
#  '팔도',
#  '겹',
#  '쳐',
#  '입어서',
#  '딱히',
#  '춥진',
#  '않아요',
#  '봄가을에',
#  '입기',
#  '딱좋은',
#  '거',
#  '같아요',
#  '!',
#  '\n',
#  '팔',
#  '길이',
#  ',',
#  '전체',
#  '길이',
#  '다',
#  '적당해서',
#  '이뻐요',
#  '\n',
#  '남여',
#  '구분',
#  '없이',
#  '입',
#  '을',
#  '수',
#  '있을',
#  '것',
#  '같아서',
#  '좋은',
#  '듯',
#  '\n',
#  '검은색',
#  '맨',
#  '투맨',
#  '고민',
#  '할',
#  '필요',
#  '가',
#  '있나여',
#  '??',
#  '\n',
#  '마크',
#  '곤잘레스',
#  '원툴',
#  '로',
#  '가야',
#  '하는거',
#  '아닌가여',
#  '?',
#  '\n',
#  '스몰',
#  '로고',
#  '가',
#  '너무',
#  '귀여워여',
#  '!!',
#  '\n',
#  '로고',
#  '가',
#  '깔끔하게',
#  '들어가서',
#  '이뻐요',
#  '사이즈',
#  '도',
#  '딱입니다',
#  '\n',
#  '동생',
#  '주',
#  '려고',
#  '구매',
#  '했어요',
#  '딱',
#  '예쁘게',
#  '잘',
#  '맞아요',
#  '색깔',
#  '이',
#  '예쁘네요',
#  '\n',
#  '생각',
#  '보단',
#  '살짝',
#  '크긴',
#  '한데',
#  '재질',
#  '도',
#  '좋고',
#  '정말',
#  '편해요',
#  '\n',
#  '무난',
#  '무난',
#  '한',
#  '검정',
#  '맨',
#  '투',
#  '맨입',
#  '니',
#  '다',
#  '블프때',
#  '싸게',
#  '잘',
#  '샀네요',
#  '\n',
#  '레이어',
#  '드',
#  '해서',
#  '입기',
#  '좋아요',
#  '.',
#  '재질',
#  '도',
#  '좋고',
#  '세탁',
#  '후',
#  '변형도',
#  '없어요',
#  '.',
#  '\n',
#  '강',
#  '추합니다',
#  '.',
#  '\n',
#  '블랙프라이데이',
#  '세',
#  '일로',
#  '저렴하게',
#  '구매',
#  '했구',
#  '별',
#  '기대',
#  '안',
#  '했는데',
#  '핏',
#  '도',
#  '예쁘고',
#  '넘',
#  '좋',
#  '습',
#  '니당',
#  '\n',
#  '마크',
#  '곤잘레스',
#  '가',
#  '교복',
#  '인가',
#  '봐요',
#  '..',
#  '\n',
#  '아드님',
#  '사',
#  '드렸더니',
#  '좋아해요',
#  '\n',
#  '완전',
#  '편하고',
#  '부드러워서',
#  '자주',
#  '입고',
#  '다녀요',
#  '아주',
#  '좋습니다',
#  '\n',
#  '진짜',
#  '좋음',
#  '예쁘고',
#  '딱',
#  '좋아요',
#  '여러분',
#  '다',
#  '사',
#  '는걸',
#  '추천',
#  '함',
#  '가격',
#  '대',
#  '비도',
#  '나쁘지',
#  '않아요',
#  '\n',
#  '정말',
#  '편하고',
#  '핏감',
#  '도',
#  '좋네요',
#  '.',
#  '마크',
#  '곤잘레스',
#  '느낌',
#  '살아요',
#  '짱짱',
#  '\n',
#  '할인',
#  '한',
#  '김',
#  '에',
#  '샀는데',
#  '핏',
#  '도',
#  '좋고',
#  '두께',
#  '도',
#  '좋고',
#  '적당히',
#  '입을것',
#  '같습니다',
#  '\n',
#  '딱',
#  '좋습니다',
#  '안감',
#  '도',
#  '좋고',
#  '재질',
#  '도',
#  '좋아요',
#  '만족합니다',
#  '\n',
#  '소재',
#  '좋고',
#  '배송',
#  '빠르고',
#  '\n',
#  '핏',
#  '도',
#  '넘',
#  '예뻐요',
#  '.',
#  '만족해요',
#  '.',
#  '\n',
#  '뒷',
#  '로고',
#  '도',
#  '예뻐요',
#  '~',
#  '\n',
#  '사이즈',
#  '가',
#  '딱',
#  '맞아서',
#  '정사',
#  '이즈',
#  '를',
#  '구매',
#  '하시는것을',
#  '추천',
#  '드립니다',
#  '\n',
#  '딱',
#  '정',
#  '핏이구',
#  '요',
#  '177',
#  '에',
#  '70',
#  '중',
#  '후반',
#  '\n',
#  '핏감',
#  '되게',
#  '좋게',
#  '나왔어요',
#  '롯데',
#  '마트',
#  '가서',
#  '사는',
#  '11',
#  '자핏',
#  '\n',
#  '그런',
#  '핏',
#  '이',
#  '아니라',
#  '어깨',
#  '살짝',
#  '넘어가는',
#  '그런',
#  '핏',
#  '\n',
#  '어깡들',
#  '은',
#  '타이',
#  '트',
#  '할수있는',
#  '그런',
#  '핏',
#  '\n',
#  '오',
#  '버핏',
#  '좋아하시면',
#  'xL',
#  '추천',
#  '\n',
#  '재질',
#  '은',
#  '부드럽고',
#  '낫',
#  '배드',
#  '함',
#  '\n',
#  '바닥',
#  '에',
#  '놔두면',
#  '먼지',
#  '묻음',
#  '\n',
#  '좋고',
#  '무난',
#  '한',
#  '옷',
#  '\n',
#  '오',
#  ...]

# %%
ko = nltk.Text(tokens_ko)
ko.vocab().most_common(100)    # 가장 많이 나온 단어 100개
# Out:
# [('\n', 134),
#  ('도', 47),
#  ('.', 44),
#  ('이', 35),
#  ('에', 31),
#  ('너무', 26),
#  ('잘', 25),
#  ('가', 23),
#  ('맨', 21),
#  ('마크', 18),
#  ('!', 18),
#  ('좋아요', 18),
#  ('딱', 17),
#  ('좋고', 17),
#  ('사이즈', 17),
#  ('곤잘레스', 16),
#  ('옷', 16),
#  ('무난', 15),
#  ('입기', 15),
#  ('같아요', 13),
#  ('핏', 13),
#  ('투맨', 12),
#  ('입고', 12),
#  ('로고', 12),
#  ('요', 11),
#  ('한', 11),
#  ('다', 11),
#  ('오', 11),
#  ('버핏', 11),
#  ('안', 9),
#  ('은', 9),
#  ('을', 9),
#  ('맘', 9),
#  ('편하게', 8),
#  ('으로', 8),
#  ('좋습니다', 8),
#  ('색감', 8),
#  ('들어요', 8),
#  ('가격', 7),
#  ('것', 7),
#  ('투', 7),
#  ('로', 7),
#  ('~', 7),
#  ('이뻐요', 7),
#  ('해', 6),
#  ('수', 6),
#  ('구매', 6),
#  ('샀는데', 6),
#  ('이쁩니다', 6),
#  ('디자인', 6),
#  ('재질', 6),
#  ('살짝', 5),
#  ('거', 5),
#  ('있어요', 5),
#  ('나쁘지', 5),
#  ('않고', 5),
#  ('이쁘고', 5),
#  ('용', 5),
#  ('맨입', 5),
#  ('니', 5),
#  ('자주', 5),
#  ('얇지도', 5),
#  ('편하고', 5),
#  ('두께', 5),
#  ('회색', 5),
#  ('..', 5),
#  ('스타일', 5),
#  ('들', 5),
#  ('심플', 5),
#  ('역시', 4),
#  ('여서', 4),
#  ('사서', 4),
#  ('싸게', 4),
#  ('감', 4),
#  ('특히', 4),
#  ('흰', 4),
#  ('티', 4),
#  ('좋은', 4),
#  ('해요', 4),
#  ('정도', 4),
#  ('않을', 4),
#  ('맞고', 4),
#  ('네', 4),
#  ('입', 4),
#  ('적당한', 4),
#  ('깔끔하고', 4),
#  ('가을', 4),
#  ('하', 4),
#  ('좋아서', 4),
#  ('다른', 4),
#  ('색상', 4),
#  ('이쁘네요', 4),
#  ('좀', 4),
#  ('생각', 4),
#  ('길이', 4),
#  ('스몰', 4),
#  ('정말', 4),
#  ('추천', 4),
#  ('좋네요', 4),
#  ('느낌', 4)]

# %%
# 불용어 : 인터넷 검색 시 검색 용어로 사용하지 않는 단어. 관사, 전치사, 조사, 접속사 등 검색 색인 단어로 의미가 없는 단어
stop_words = ['.',' ', '\n','\n ', '않아서','nan','가','요','답변','...','을','수','에','질문','제','를','이','도',
                      '좋','1','는','로','으로','2','것','은','다',',','니다','대','들',
                      '2017','들','데','..','의','때','겠','고','게','네요','한','일','할',
                      '10','?','하는','06','주','려고','인데','거','좀','는데','~','ㅎㅎ',
                      '하나','이상','20','뭐','까','있는','잘','습니다','다면','했','주려',
                      '지','있','못','후','것','투','로','줄','6','과','어떤','기본','!',
                      '단어','네','하','중요한','합','같아요','....','보이','네','무지','맨','너무']

tokens_ko = [each_word for each_word in tokens_ko
             if each_word not in stop_words]

ko = nltk.Text(tokens_ko)
ko.vocab().most_common(50)
# Out:
# [('마크', 18),
#  ('좋아요', 18),
#  ('딱', 17),
#  ('좋고', 17),
#  ('사이즈', 17),
#  ('곤잘레스', 16),
#  ('옷', 16),
#  ('무난', 15),
#  ('입기', 15),
#  ('핏', 13),
#  ('투맨', 12),
#  ('입고', 12),
#  ('로고', 12),
#  ('오', 11),
#  ('버핏', 11),
#  ('안', 9),
#  ('맘', 9),
#  ('편하게', 8),
#  ('좋습니다', 8),
#  ('색감', 8),
#  ('들어요', 8),
#  ('가격', 7),
#  ('이뻐요', 7),
#  ('해', 6),
#  ('구매', 6),
#  ('샀는데', 6),
#  ('이쁩니다', 6),
#  ('디자인', 6),
#  ('재질', 6),
#  ('살짝', 5),
#  ('있어요', 5),
#  ('나쁘지', 5),
#  ('않고', 5),
#  ('이쁘고', 5),
#  ('용', 5),
#  ('맨입', 5),
#  ('니', 5),
#  ('자주', 5),
#  ('얇지도', 5),
#  ('편하고', 5),
#  ('두께', 5),
#  ('회색', 5),
#  ('스타일', 5),
#  ('심플', 5),
#  ('역시', 4),
#  ('여서', 4),
#  ('사서', 4),
#  ('싸게', 4),
#  ('감', 4),
#  ('특히', 4)]

# %%
plt.figure(figsize=(15,6))
ko.plot(50) 
plt.show()

# %%
data = ko.vocab().most_common(300)
data
# Out:
# [('마크', 18),
#  ('좋아요', 18),
#  ('딱', 17),
#  ('좋고', 17),
#  ('사이즈', 17),
#  ('곤잘레스', 16),
#  ('옷', 16),
#  ('무난', 15),
#  ('입기', 15),
#  ('핏', 13),
#  ('투맨', 12),
#  ('입고', 12),
#  ('로고', 12),
#  ('오', 11),
#  ('버핏', 11),
#  ('안', 9),
#  ('맘', 9),
#  ('편하게', 8),
#  ('좋습니다', 8),
#  ('색감', 8),
#  ('들어요', 8),
#  ('가격', 7),
#  ('이뻐요', 7),
#  ('해', 6),
#  ('구매', 6),
#  ('샀는데', 6),
#  ('이쁩니다', 6),
#  ('디자인', 6),
#  ('재질', 6),
#  ('살짝', 5),
#  ('있어요', 5),
#  ('나쁘지', 5),
#  ('않고', 5),
#  ('이쁘고', 5),
#  ('용', 5),
#  ('맨입', 5),
#  ('니', 5),
#  ('자주', 5),
#  ('얇지도', 5),
#  ('편하고', 5),
#  ('두께', 5),
#  ('회색', 5),
#  ('스타일', 5),
#  ('심플', 5),
#  ('역시', 4),
#  ('여서', 4),
#  ('사서', 4),
#  ('싸게', 4),
#  ('감', 4),
#  ('특히', 4),
#  ('흰', 4),
#  ('티', 4),
#  ('좋은', 4),
#  ('해요', 4),
#  ('정도', 4),
#  ('않을', 4),
#  ('맞고', 4),
#  ('입', 4),
#  ('적당한', 4),
#  ('깔끔하고', 4),
#  ('가을', 4),
#  ('좋아서', 4),
#  ('다른', 4),
#  ('색상', 4),
#  ('이쁘네요', 4),
#  ('생각', 4),
#  ('길이', 4),
#  ('스몰', 4),
#  ('정말', 4),
#  ('추천', 4),
#  ('좋네요', 4),
#  ('느낌', 4),
#  ('같습니다', 4),
#  ('희', 4),
#  ('실루엣', 4),
#  ('그런지', 3),
#  ('하네요', 3),
#  ('블랙', 3),
#  ('듯', 3),
#  ('분', 3),
#  ('이에요', 3),
#  ('정사', 3),
#  ('이즈', 3),
#  ('기장', 3),
#  ('두껍지도', 3),
#  ('교복', 3),
#  ('입니다', 3),
#  ('감도', 3),
#  ('마음', 3),
#  ('듭니', 3),
#  ('검정', 3),
#  ('레이어', 3),
#  ('드', 3),
#  ('하기', 3),
#  ('!!', 3),
#  ('동생', 3),
#  ('보', 3),
#  ('어깨', 3),
#  ('맞아요', 3),
#  ('보단', 3),
#  ('사는', 3),
#  ('예쁘고', 3),
#  ('사진', 3),
#  ('이랑', 3),
#  ('배송', 3),
#  ('했는데', 3),
#  ('더', 3),
#  ('시', 3),
#  ('보리', 3),
#  ('않아요', 3),
#  ('검은색', 3),
#  ('넘', 3),
#  ('진짜', 3),
#  ('예뻐요', 3),
#  ('맞아서', 3),
#  ('그런', 3),
#  ('보다', 3),
#  ('ㅠㅠ', 3),
#  ('적당하고', 3),
#  ('지만', 3),
#  ('어디', 3),
#  ('편해서', 3),
#  ('앞', 3),
#  ('하고', 3),
#  ('포인트', 3),
#  ('이라서', 3),
#  ('확실히', 2),
#  ('예쁘긴', 2),
#  ('프라이데이', 2),
#  ('샀구요', 2),
#  ('이해', 2),
#  ('되긴', 2),
#  ('하지만', 2),
#  ('비싼', 2),
#  ('없지', 2),
#  ('않나', 2),
#  ('랑', 2),
#  ('궁합', 2),
#  ('요즘', 2),
#  ('날씨', 2),
#  ('밖에', 2),
#  ('나갈', 2),
#  ('어느', 2),
#  ('돈', 2),
#  ('넉넉하신', 2),
#  ('걸', 2),
#  ('선택', 2),
#  ('커플티', 2),
#  ('맞췃는데', 2),
#  ('좋았어요', 2),
#  ('있어서', 2),
#  ('손', 2),
#  ('갑니다', 2),
#  ('가성', 2),
#  ('비갑', 2),
#  ('엄청', 2),
#  ('일리', 2),
#  ('거의', 2),
#  ('두껍거나', 2),
#  ('않은', 2),
#  ('얇아서', 2),
#  ('무낭', 2),
#  ('사고', 2),
#  ('샀어요', 2),
#  ('똑같은', 2),
#  ('또', 2),
#  ('다시', 2),
#  ('재구매', 2),
#  ('했습니다', 2),
#  ('예뻐서', 2),
#  ('계속', 2),
#  ('사게', 2),
#  ('되네요', 2),
#  ('저희', 2),
#  ('애가', 2),
#  ('조금', 2),
#  ('근육', 2),
#  ('있다', 2),
#  ('니깐', 2),
#  ('옷핏', 2),
#  ('서네요', 2),
#  ('3', 2),
#  ('600', 2),
#  ('침', 2),
#  ('좁아서', 2),
#  ('믿고', 2),
#  ('블프때', 2),
#  ('괜찮네요', 2),
#  ('구입', 2),
#  ('만족합니다', 2),
#  ('뱃살', 2),
#  ('입으면', 2),
#  ('ㅋㅋ', 2),
#  ('적당해서', 2),
#  ('하는거', 2),
#  ('색깔', 2),
#  ('세', 2),
#  ('사', 2),
#  ('아주', 2),
#  ('함', 2),
#  ('핏감', 2),
#  ('괜찮아서', 2),
#  ('기', 2),
#  ('본', 2),
#  ('이라', 2),
#  ('두루', 2),
#  ('입어도', 2),
#  ('완벽합니다', 2),
#  ('참고', 2),
#  ('하시면', 2),
#  ('작어서', 2),
#  ('…', 2),
#  ('예뻐여', 2),
#  ('하구', 2),
#  ('브랜드', 2),
#  ('꺼', 2),
#  ('급', 2),
#  ('필이었는데', 2),
#  ('다닐게', 2),
#  ('이쁜데', 2),
#  ('찍느라', 2),
#  ('나왔네요', 2),
#  ('ㅜ', 2),
#  ('괜찮아요', 2),
#  ('영어', 2),
#  ('사촌동생', 2),
#  ('사줬는데', 2),
#  ('~~', 2),
#  ('큰', 2),
#  ('편이', 2),
#  ('…!', 2),
#  ('에나', 2),
#  ('어울리고', 2),
#  ('후회', 2),
#  ('하지', 2),
#  ('으로도', 2),
#  ('입을꺼', 2),
#  ('뻣뻣하지', 2),
#  ('부들부들해요', 2),
#  ('쨍하', 2),
#  ('않게', 2),
#  ('하니', 2),
#  ('빠졌어요', 2),
#  ('줘서', 2),
#  ('덩치', 2),
#  ('있으시면', 2),
#  ('껴요', 2),
#  ('슬림', 2),
#  ('신분', 2),
#  ('걸치는', 2),
#  ('입으시면', 2),
#  ('좋을듯', 2),
#  ('넉넉하고', 2),
#  ('에도', 2),
#  ('에는', 2),
#  ('같기도', 2),
#  ('후드', 1),
#  ('많이', 1),
#  ('역시군요', 1),
#  ('기모', 1),
#  ('나쁘지는', 1),
#  ('않은데', 1),
#  ('애매함', 1),
#  ('총장', 1),
#  ('짧은', 1),
#  ('편', 1),
#  ('마곤', 1),
#  ('마니', 1),
#  ('퀄리티', 1),
#  ('컬러', 1),
#  ('굿', 1),
#  ('활용', 1),
#  ('높고', 1),
#  ('있습니다', 1),
#  ('굿굿', 1),
#  ('크네요', 1),
#  ('입기에는', 1),
#  ('다운', 1),
#  ('해도', 1),
#  ('괜찮겠어요', 1),
#  ('똑같고', 1),
#  ('맞는', 1),
#  ('빨라요', 1),
#  ('검정색', 1),
#  ('만족해서', 1),
#  ('만족스럽네요', 1),
#  ('착용', 1),
#  ('하면', 1),
#  ('있고', 1),
#  ('없어서', 1),
#  ('만족스럽', 1),
#  ('개심', 1),
#  ('올려', 1),
#  ('커버', 1),
#  ('해줘요', 1),
#  ('실', 1),
#  ('측', 1),
#  ('보고', 1),
#  ('M', 1),
#  ('L', 1)]

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %%
import matplotlib.pyplot as plt

from matplotlib import font_manager

font_fname = 'c:/Windows/Fonts/malgun.ttf'

font_family = font_manager.FontProperties(fname=font_fname).get_name()

plt.rcParams["font.family"] = font_family

# %%
wordcloud = WordCloud(font_path='malgun',  # 윈도우:'c:/Windows/Fonts/malgun.ttf'
                      relative_scaling = 0.2, 
                      #stopwords=STOPWORDS,
                      background_color='white'
                      ).generate_from_frequencies(dict(data))
plt.figure(figsize=(16,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
import re 
# 텍스트 값 리스트로 변환
result=[]
res = [] 
height_list = Mans.height.values.tolist()
# cm 빼고 정수형으로 전환 
for i in range(len(height_list)):
    result.append(re.findall('\d+',height_list[i]))
    res.append(int(result[i][0]))
print(res)
# Out:
# [178, 178, 182, 165, 170, 163, 170, 175, 175, 178, 178, 182, 165, 170, 163, 170, 175, 175, 174, 180, 184, 177, 181, 170, 171, 178, 174, 166, 178, 173, 175, 167, 172, 173, 171, 180, 177, 178, 187, 177, 173, 178, 181, 174, 186, 164, 180, 184, 177, 189, 181, 174, 186, 164, 180, 184, 177, 189, 187, 177, 183, 178, 168, 170, 171, 173, 173, 189, 179, 170, 179, 170, 178, 174, 180, 176]

# %%
# cm 빼고 정수형으로 전환 
weight_list = Mans.weight.values.tolist()
result2 = []
res2 = []
for i in range(len(weight_list)):
    result2.append((re.findall('\d+',weight_list[i])))
    res2.append(int(result2[i][0]))
print(res2)
# Out:
# [62, 60, 72, 80, 65, 44, 65, 70, 85, 62, 60, 72, 80, 65, 44, 65, 70, 85, 56, 72, 80, 72, 83, 50, 58, 65, 75, 51, 74, 70, 80, 68, 60, 63, 60, 70, 80, 80, 83, 75, 64, 70, 78, 70, 82, 65, 82, 95, 75, 127, 78, 70, 82, 65, 82, 95, 75, 127, 95, 60, 78, 88, 63, 66, 66, 70, 70, 95, 70, 63, 73, 65, 67, 78, 73, 86]

# %%
# 기존 키 무게 삭제
Mans = Mans.drop(['height','weight'],axis=1)

# %%
# 새로운 정수형 키 추가 
Mans.insert(1,'height',res)

# %%
# 정수형 무게 추가 
Mans.insert(2,'weight',res2)

# %%
Mans
# Out:
#    gender  height  weight    fit size
# 0      남성     178      62     커요    L
# 2      남성     178      60  보통이에요    M
# 3      남성     182      72  보통이에요    L
# 4      남성     165      80  보통이에요   XL
# 5      남성     170      65     커요    M
# ..    ...     ...     ...    ...  ...
# 85     남성     170      65  보통이에요    M
# 86     남성     178      67  보통이에요    L
# 87     남성     174      78  보통이에요   XL
# 88     남성     180      73     커요    L
# 89     남성     176      86  보통이에요    L
#
# [76 rows x 5 columns]

# %%
#각 갯수 만큼 counts
big = (Mans.height >= 165) & (Mans.height < 175) & (Mans['size']== 'S')
mid = (Mans.height >= 165) & (Mans.height < 175) & (Mans['size']=='M')
small = (Mans.height >= 165) & (Mans.height < 175) & (Mans['size']== 'M')

big_counts = Mans.loc[big]
big_counts['counts']=1
mid_counts = Mans.loc[mid]
mid_counts['counts']=1
sm_counts = Mans.loc[small]
sm_counts['counts']=1

# 사이즈별 데이터 프레임 병합
satis_count = pd.concat([big_counts,mid_counts,sm_counts])

# %%
satis_count
satis_165_175 = satis_count[['fit','size','counts']]

# %%
ans = satis_165_175.groupby(['fit','size']).sum()
ans
# Out:
#             counts
# fit   size
# 보통이에요 M         22
#       S          3
# 커요    M          6

# %%
#한글 꺠짐 방지
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False
 
# 차트 종류, 제목, 차트 크기, 범례, 폰트 크기 설정
ax = ans.plot(kind='bar', title='남자 사이즈 만족도', figsize=(20, 5), legend=True, fontsize=20)
ax.set_xlabel('165~175cm 사이즈', fontsize=15)          # x축 정보 표시
plt.xticks(rotation=0)
plt.yticks(rotation=90)
h= plt.ylabel('사이즈 수 ', fontsize=12)     # y축 정보 표시
h.set_rotation(0)
ax.legend(['각 사이즈 만족도 수'], fontsize=12)    # 범례 지정

# %% [markdown]
# 데이터 시각화로  165~175cm인 사람들은 이 옷 구매시
# M 사이즈면 딱 맞는다는 것을 한눈에 확인 가능하다.

# %%
Girls
# Out:
#    gender height weight    fit size
# 1      여성  165cm   50kg  보통이에요    S
# 11     여성  165cm   50kg  보통이에요    S
# 29     여성  160cm   74kg  보통이에요    M
# 36     여성  168cm   45kg  보통이에요    M
# 37     여성  162cm   54kg  보통이에요    S
# 39     여성  164cm   56kg     커요    M
# 44     여성  164cm   47kg     커요    S
# 49     여성  160cm   60kg  보통이에요    S
# 53     여성  158cm   50kg  보통이에요    S
# 56     여성  157cm   57kg     커요   XL
# 63     여성  158cm   50kg  보통이에요    S
# 66     여성  157cm   57kg     커요   XL
# 72     여성  167cm   51kg  보통이에요    M
# 74     여성  171cm   58kg  보통이에요    M

# %%
# 텍스트 값 리스트로 변환
G_result=[]
G_res = [] 
G_height_list = Girls.height.values.tolist()
# cm 빼고 정수형으로 전환 
for i in range(len(G_height_list)):
    G_result.append(re.findall('\d+',G_height_list[i]))
    G_res.append(int(G_result[i][0]))

# cm 빼고 정수형으로 전환 
G_weight_list = Girls.weight.values.tolist()
G_result2 = []
G_res2 = []
for i in range(len(G_weight_list)):
    G_result2.append((re.findall('\d+',G_weight_list[i])))
    G_res2.append(int(G_result2[i][0]))

# %%
# 기존 키 무게 삭제
Girls = Girls.drop(['height','weight'],axis=1)

# %%
# 새로운 정수형 키 추가 
Girls.insert(1,'height',G_res)

# %%
# 정수형 무게 추가 
Girls.insert(2,'weight',G_res2)

# %%
Girls
# Out:
#    gender  height  weight    fit size
# 1      여성     165      50  보통이에요    S
# 11     여성     165      50  보통이에요    S
# 29     여성     160      74  보통이에요    M
# 36     여성     168      45  보통이에요    M
# 37     여성     162      54  보통이에요    S
# 39     여성     164      56     커요    M
# 44     여성     164      47     커요    S
# 49     여성     160      60  보통이에요    S
# 53     여성     158      50  보통이에요    S
# 56     여성     157      57     커요   XL
# 63     여성     158      50  보통이에요    S
# 66     여성     157      57     커요   XL
# 72     여성     167      51  보통이에요    M
# 74     여성     171      58  보통이에요    M

# %%
#각 갯수 만큼 counts
big = (Girls.height >= 165) & (Girls.height < 175) & (Girls['size']== 'S')
mid = (Girls.height >= 165) & (Girls.height < 175) & (Girls['size']=='M')
small = (Girls.height >= 165) & (Girls.height < 175) & (Girls['size']== 'M')

big_counts = Girls.loc[big]
big_counts['counts']=1
mid_counts = Girls.loc[mid]
mid_counts['counts']=1
sm_counts = Girls.loc[small]
sm_counts['counts']=1

# 사이즈별 데이터 프레임 병합
G_satis_count = pd.concat([big_counts,mid_counts,sm_counts])

# %%
G_satis_165_175 = satis_count[['fit','size','counts']]

# %%
G_ans = G_satis_165_175.groupby(['fit','size']).sum()

# %%
G_ans
# Out:
#             counts
# fit   size
# 보통이에요 M          6
#       S          2

# %%
#한글 꺠짐 방지
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False
 
# 차트 종류, 제목, 차트 크기, 범례, 폰트 크기 설정
ax = G_ans.plot(kind='bar', title='여자 사이즈 만족도', figsize=(20, 5), legend=True, fontsize=20)
ax.set_xlabel('165~175cm 사이즈', fontsize=15)          # x축 정보 표시
plt.xticks(rotation=0)
plt.yticks(rotation=90)
h= plt.ylabel('사이즈 수 ', fontsize=12)     # y축 정보 표시
h.set_rotation(0)
ax.legend(['각 사이즈 만족도 수'], fontsize=12)    # 범례 지정

# %% [markdown]
# 여성구매자 신장 165~175cm의 구매자들의 만족도를 시각화하여 보였다.

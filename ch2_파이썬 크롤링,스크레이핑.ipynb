# %% [markdown]
# # ch2.4 웹 페이지 스크레이핑

# %% [markdown]
# # meta 태그에서 인코딩 방식 추출하기

# %% [raw]
# 한빛출판사 홈페이지 웹 크롤링해보기

# %%
import sys
from urllib.request import urlopen

# urlopen() 함수는 HTTPResponse 자료형의 객체를 반환합니다.
f = urlopen('http://www.hanbit.co.kr/store/books/full_book_list.html')
# bytes 자료형의 응답 본문을 일단 변수에 저장합니다.
bytes_content = f.read()  
bytes_content
# Out:
# b'<!DOCTYPE html>\r\n<html lang="ko">\r\n<head>\r\n<!--[if lte IE 8]>\r\n<script>\r\n  location.replace(\'/support/explorer_upgrade.html\');\r\n</script>\r\n<![endif]-->\r\n<meta charset="utf-8"/>\r\n<title>\xed\x95\x9c\xeb\xb9\x9b\xec\xb6\x9c\xed\x8c\x90\xeb\x84\xa4\xed\x8a\xb8\xec\x9b\x8c\xed\x81\xac</title>\r\n<link rel="shortcut icon" href="https://www.hanbit.co.kr/images/common/hanbit.ico"> \r\n<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\r\n<meta property="og:type" content="website"/>\r\n<meta property="og:title" content="\xed\x95\x9c\xeb\xb9\x9b\xec\xb6\x9c\xed\x8c\x90\xeb\x84\xa4\xed\x8a\xb8\xec\x9b\x8c\xed\x81\xac"/>\r\n<meta property="og:description" content="\xeb\x8d\x94 \xeb\x84\x93\xec\x9d\x80 \xec\x84\xb8\xec\x83\x81, \xeb\x8d\x94 \xeb\x82\x98\xec\x9d\x80 \xeb\xaf\xb8\xeb\x9e\x98\xeb\xa5\xbc \xec\x9c\x84\xed\x95\x9c \xec\x95\x84\xec\x8b\x9c\xec\x95\x84 \xec\xb6\x9c\xed\x8c\x90 \xeb\x84\xa4\xed\x8a\xb8\xec\x9b\x8c\xed\x81\xac :: \xed\x95\x9c\xeb\xb9\x9b\xeb\xaf\xb8\xeb\x94\x94\xec\x96\xb4, \xed\x95\x9c\xeb\xb9\x9b\xec\x95\x84\xec\xb9\xb4\xeb\x8d\xb0\xeb\xaf\xb8, \xed\x95\x9c\xeb\xb9\x9b\xeb\xb9\x84\xec\xa6\x88, \xed\x95\x9c\xeb\xb9\x9b\xeb\x9d\xbc\xec\x9d\xb4\xed\x94\x84, \xed\x95\x9c\xeb\xb9\x9b\xec\x97\x90\xeb\x93\x80"/>\r\n<meta property="og:image" content="https://www.hanbit.co.kr/images/hanbitpubnet_logo.jpg" />\r\n<meta property="og:url" content="https://www.hanbit.co.kr/store/books/full_book_list.html"/>\r\n<link rel="canonical" href="https://www.hanbit.co.kr/store/books/full_book_list.html" />\r\n<meta name="keywords" content="\xed\x95\x9c\xeb\xb9\x9b\xeb\xaf\xb8\xeb\x94\x94\xec\x96\xb4,\xed\x95\x9c\xeb\xb9\x9b\xec\x95\x84\xec\xb9\xb4\xeb\x8d\xb0\xeb\xaf\xb8,\xed\x95\x9c\xeb\xb9\x9b\xeb\xb9\x84\xec\xa6\x88,\xed\x95\x9c\xeb\xb9\x9b\xeb\x9d\xbc\xec\x9d\xb4\xed\
# charset은 HTML의 앞부분에 적혀 있는 경우가 많으므로 응답 본문의 앞부분 1024바이트를 ASCII 문자로 디코딩해 둡니다.
# ASCII 범위 이위의 문자는 U+FFFD(REPLACEMENT CHARACTER)로 변환되어 예외가 발생하지 않습니다.
scanned_text = bytes_content[:1024].decode('ascii', errors='replace')
scanned_text
# Out:
# '<!DOCTYPE html>\r\n<html lang="ko">\r\n<head>\r\n<!--[if lte IE 8]>\r\n<script>\r\n  location.replace(\'/support/explorer_upgrade.html\');\r\n</script>\r\n<![endif]-->\r\n<meta charset="utf-8"/>\r\n<title>������������������������</title>\r\n<link rel="shortcut icon" href="https://www.hanbit.co.kr/images/common/hanbit.ico"> \r\n<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\r\n<meta property="og:type" content="website"/>\r\n<meta property="og:title" content="������������������������"/>\r\n<meta property="og:description" content="��� ������ ������, ��� ������ ��������� ������ ��������� ������ ������������ :: ���������������, ������������������, ������������, ���������������, ������������"/>\r\n<meta property="og:image" content="https://www.hanbit.co.kr/images/hanbitpubnet_logo.jpg" />\r\n<meta property="og:url" content="https://www.hanbit.co.kr/store/books/full_book_list.html"/>\r\n<link rel="canonical" href="https://www.hanbit.co.kr/store/books/full_book_list.html" />\r\n<meta name="keywords" content="���������������,������������������,��'

# %%
import re

# 디코딩한 문자열에서 정규 표현식으로 charset 값을 추출합니다.
match = re.search('charset=["\']?([\w-]+)', scanned_text)
match
# ["\']?  : 홑따옴표나 쌍따옴표 0 또는 1번 반복
# ([\w-]+)  : 알파벳,숫자,언더바(_),대쉬(-) 한 번 이상 반복 그룹
# Out:
# <re.Match object; span=(159, 173), match='charset="utf-8'>

# %%
# match(charset)가 존재하는 경우
if match:
    encoding = match.group(1)
else:
    # charset이 명시돼 있지 않으면 UTF-8을 사용합니다.
    encoding = 'utf-8'

# %%
match.group(1)
# Out:
# 'utf-8'

# %%
# 추출한 인코딩을 표준 오류에 출력합니다.
print('encoding:', encoding, file=sys.stderr)
# Out:
# encoding: utf-8

# %%
# 추출한 인코딩으로 다시 디코딩합니다.
text_html = bytes_content.decode(encoding)
# 응답 본문을 표준 출력에 출력합니다.
print(text_html)
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <!--[if lte IE 8]>
# <script>
#   location.replace('/support/explorer_upgrade.html');
# </script>
# <![endif]-->
# <meta charset="utf-8"/>
# <title>한빛출판네트워크</title>
# <link rel="shortcut icon" href="https://www.hanbit.co.kr/images/common/hanbit.ico">
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta property="og:type" content="website"/>
# <meta property="og:title" content="한빛출판네트워크"/>
# <meta property="og:description" content="더 넓은 세상, 더 나은 미래를 위한 아시아 출판 네트워크 :: 한빛미디어, 한빛아카데미, 한빛비즈, 한빛라이프, 한빛에듀"/>
# <meta property="og:image" content="https://www.hanbit.co.kr/images/hanbitpubnet_logo.jpg" />
# <meta property="og:url" content="https://www.hanbit.co.kr/store/books/full_book_list.html"/>
# <link rel="canonical" href="https://www.hanbit.co.kr/store/books/full_book_list.html" />
# <meta name="keywords" content="한빛미디어,한빛아카데미,한빛비즈,한빛라이프,한빛에듀,리얼타임,대관서비스,책,출판사,IT전문서,IT활용서,대학교재,경제경영,어린이/유아,실용/여행,전자책,자격증,교육,세미나,강의,ebook,정보교과서" />
# <meta name="description" content="더 넓은 세상, 더 나은 미래를 위한 아시아 출판 네트워크 :: 한빛미디어, 한빛아카데미, 한빛비즈, 한빛라이프, 한빛에듀" />
# <meta name="viewport" content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0">
# <meta name="viewport" content="width=1260">
# <meta name="apple-mobile-web-app-capable" content="yes" />
# <meta name="naver-site-verification" content="01c29ed1852aecca7a48ac0c3e0869627bc512d8"/>
# <link rel="stylesheet" href="/css/common.css?20210603093421" />
# <link href="/css/hover.css" rel="stylesheet" media="all">
# <link rel="stylesheet" href="/js/jquery.raty.css" />
# <script type="text/javascript" src="/js/jquery-latest.js"></script>
# <script type="text/javascript" src="/js/jquery-ui.js"></script>
# <script type="text/javascript" src="/js/jquery.event.drag-1.5.min.js"></script>
# <script type="text/javascript" src="/js/jquery.touchSlider.js"></script>
# <script type="text/javascript" src="/js/jquery.raty.js"></script>
# <script type="text/javascript" src="/js/main.js"></script>
# <script type="text/javascript" src="/lib/cheditor/cheditor.js"></script>
# <script type="text/javascript" src="/js/jquery.ui.datepicker-ko.js"></script>
# <script type="text/javascript" src="/js/engine.js"></script>
# <script type="text/javascript" src="/js/vue.js"></script>
#
# <!-- Google Analytics -->
# <script>
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
# ga('create', 'UA-47080738-1', 'hanbit.co.kr');
# ga('require', 'linkid', 'linkid.js');
# ga('send', 'pageview');
# </script>
# <!-- Google Analytics -->
#
# <!-- Facebook Pixel Code -->
# <script>
#   !function(f,b,e,v,n,t,s)
#   {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#   if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#   n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];
#   s.parentNode.insertBefore(t,s)}(window, document,'script',
#   'https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '406459623338891');
#   fbq('track', 'PageView');
# </script>
# <noscript><img height="1" width="1" style="display:none"
#   src="https://www.facebook.com/tr?id=406459623338891&ev=PageView&noscript=1"
# /></noscript>
# <!-- End Facebook Pixel Code -->
#
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-W9D5PM3');</script>
# <!-- End Google Tag Manager -->
#
# <!-- Kakao Pixel Code -->
# <script type="text/javascript" charset="UTF-8" src="//t1.daumcdn.net/adfit/static/kp.js"></script>
# <script type="text/javascript">
#   kakaoPixel('3011392806152551233').pageView();
# </script>
# <!-- //Kakao Pixel Code -->
# </head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-W9D5PM3"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <link rel="stylesheet" href="/css/layout-hanbit.css?202107291450" />
# <link rel="stylesheet" href="/css/layout-member.css" />
# <link rel="stylesheet" href="/css/layout-network.css" />
# <link rel="stylesheet" href="/css/layout-store.css" />
# <link rel="stylesheet" href="/css/layout-myhanbit.css" />
# <link rel="stylesheet" href="/css/layout-event.css" />
# <!-- 메뉴 바로가기 -->
# <div id="quick_skip_menu">
#   <a href="#gnb" onclick="document.getElementById('gnb').tabIndex = -1;document.getElementById('gnb').focus();return false;"><span>메뉴 바로가기</span></a>
#   <a href="#top_search" onclick="view_hover('main_search_area','','show'), document.getElementById('top_search').tabIndex = -1;document.getElementById('top_search').focus();return false;"><span>검색 및 카테고리 바로가기</span></a>
#     <a href="#container" onclick="document.getElementById('container').tabIndex = -1;document.getElementById('container').focus();return false;"><span>본문 바로가기</span></a>
#   </div>
# <!-- //메뉴 바로가기 -->
#
# <!-- header -->
# <header>
#   <!-- top menu -->
#     <nav>
#     <div id="wrap_nav">
#       <ul class="top_brand">
#         <li><a href="https://www.hanbit.co.kr/index.html" name="hanbit_network"><span>HOME</span></a></li>
#         <li><a href="https://www.hanbit.co.kr/media/">한빛미디어</a></li>
#         <li><a href="https://www.hanbit.co.kr/academy/">한빛아카데미</a></li>
#         <li><a href="https://www.hanbit.co.kr/biz/">한빛비즈</a></li>
#         <li><a href="https://www.hanbit.co.kr/life/">한빛라이프</a></li>
#         <li><a href="https://www.hanbit.co.kr/edu/">한빛에듀</a></li>
#         <li><a href="https://www.hanbit.co.kr/realtime/">리얼타임</a></li>
#         <li><a href="https://www.hanbit.co.kr/textbook/" target="_blank">한빛정보교과서</a></li>
#         <li><a href="https://www.hanbit.co.kr/rent/" target="_blank">한빛대관서비스</a></li>
#       </ul>
#
#       <ul class="top_menu">
#                 <li><a href="https://www.hanbit.co.kr/member/login.html" class="login">로그인</a></li>
#         <li><a href="https://www.hanbit.co.kr/member/member_agree.html" class="join">회원가입</a></li>
#         <li><a href="https://www.hanbit.co.kr/myhanbit/myhanbit.html" class="myhanbit">마이한빛</a></li>
#         <li><a href="https://www.hanbit.co.kr/myhanbit/cart.html" class="cart">장바구니</a></li>
#                     <li class="top_menu_store"><a href="https://www.hanbit.co.kr/publisher/foreignrights.html?lang=e" target="_blank">ENGLISH</a></li>
#       </ul>
#     </div>
#   </nav>
#   <!-- //top menu -->
#
#   <div id="wrap_gnb">
#     <!-- logo -->
#     <h1><a href="https://www.hanbit.co.kr/index.html">한빛출판네트워크</a></h1>
#     <!-- //logo -->
#
#     <!-- Menu -->
#     <div id="gnb" name="gnb">
#       <ul>
#         <li><a href="https://www.hanbit.co.kr/brand/brand_submain.html" class="">BRAND</a></li>
#         <li><a href="https://www.hanbit.co.kr/channel/channel_submain.html" class="">Channel.H</a></li>
#         <li><a href="https://www.hanbit.co.kr/store/store_submain.html" class="curr">STORE</a></li>
#         <li><a href="https://www.hanbit.co.kr/support/help_info.html" class="">SUPPORT</a></li>
#         <li><a href="https://www.hanbit.co.kr/event/current/current_event_list.html" class="">EVENT</a></li>
#
#         <li><a href="https://www.hanbit.co.kr/publisher/foreignrights.html?lang=e" class="" target="_blank">RIGHTS</a></li>
#
#         <li id="top_search" class="search"><a href="javascript:;" onClick="view_hover('main_search_area','','show'); $('#keyword_str').focus();"><span>SEARCH</span></a></li>
#       </ul>
#     </div>
#     <!-- //Menu -->
#
#     <!-- lnb -->
#     <div class="lnb" style="top:92px;">
#       <div class="lnb_area">
#       <!-- BRAND -->
#             <ul class="lnb_depth1_category">
#         <li onmouseover="view_hover('category_store','','show')" onMouseOut="view_hover('category_store','','hide')"><a href="#" onFocus="view_hover('category_store','','show')" class="gnb_category">카테고리</a>
#           <ul id="category_store">
#
#                           <li onmouseover="view_hover('category_store1','','show')" onMouseOut="view_hover('category_store1','','hide')"><a href="/store/books/category_list.html?cate_cd=001" onFocus="view_hover('category_store1','','show')">IT/모바일</a>
#                 <ul id="category_store1">
#                               <li><a href="/store/books/category_list.html?cate_cd=001001">프로그래밍</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=001002">웹</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=001003">모바일/스마트기기</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=001013">데이터베이스</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=001005">운영체제</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=001014">하드웨어</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=001015">시스템/네트워크</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=001016">보안</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=001009">비즈니스/문화</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=001010">게임</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=001017">IT에세이</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=001012">자격증</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=001018">인공지능/데이터과학</a></li>
#               </ul></li>              <li onmouseover="view_hover('category_store2','','show')" onMouseOut="view_hover('category_store2','','hide')"><a href="/store/books/category_list.html?cate_cd=002" onFocus="view_hover('category_store2','','show')">MAKE</a>
#                 <ul id="category_store2">
#                               <li><a href="/store/books/category_list.html?cate_cd=002002">Make 프로젝트 북</a></li>
#               </ul></li>              <li onmouseover="view_hover('category_store3','','show')" onMouseOut="view_hover('category_store3','','hide')"><a href="/store/books/category_list.html?cate_cd=003" onFocus="view_hover('category_store3','','show')">IT활용</a>
#                 <ul id="category_store3">
#                               <li><a href="/store/books/category_list.html?cate_cd=003001">오피스/OA</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=003002">그래픽/멀티미디어</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=003003">사진/예술</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=003004">컴퓨터입문/IT교양</a></li>
#               </ul></li>              <li onmouseover="view_hover('category_store4','','show')" onMouseOut="view_hover('category_store4','','hide')"><a href="/store/books/category_list.html?cate_cd=004" onFocus="view_hover('category_store4','','show')">대학교재</a>
#                 <ul id="category_store4">
#                               <li><a href="/store/books/category_list.html?cate_cd=004003">수학/통계</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=004010">과학/공학일반</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=004007">컴퓨터공학</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=004004">프로그래밍</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=004011">데이터과학/인공지능</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=004008">전기/전자</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=004009">기계/자동차</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=004006">OA/그래픽</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=004012">경영/경제</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=004005">논문</a></li>
#               </ul></li>              <li onmouseover="view_hover('category_store5','','show')" onMouseOut="view_hover('category_store5','','hide')"><a href="/store/books/category_list.html?cate_cd=006" onFocus="view_hover('category_store5','','show')">실용서</a>
#                 <ul id="category_store5">
#                               <li><a href="/store/books/category_list.html?cate_cd=006001">취미/실용</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=006002">여행</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=006003">건강</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=006004">유아/육아</a></li>
#               </ul></li>              <li onmouseover="view_hover('category_store6','','show')" onMouseOut="view_hover('category_store6','','hide')"><a href="/store/books/category_list.html?cate_cd=007" onFocus="view_hover('category_store6','','show')">경제/경영/인문</a>
#                 <ul id="category_store6">
#                               <li><a href="/store/books/category_list.html?cate_cd=007001">경제/경영</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=007002">자기계발</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=007003">인문/교양</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=007004">마케팅</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=007005">에세이</a></li>
#               </ul></li>              <li onmouseover="view_hover('category_store7','','show')" onMouseOut="view_hover('category_store7','','hide')"><a href="/store/books/category_list.html?cate_cd=008" onFocus="view_hover('category_store7','','show')">유아/어린이/초등</a>
#                 <ul id="category_store7">
#                               <li><a href="/store/books/category_list.html?cate_cd=008001">4~6세</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=008002">5~7세</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=008003">예비초등</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=008004">초등교과연계 1~12영역</a></li>
#                               <li><a href="/store/books/category_list.html?cate_cd=008005">초등 전학년</a></li>
#               </ul></li>
#
#           <!-- <li class="gnb_category_series"><a href="https://www.hanbit.co.kr/store/books/series_list.html">시리즈</a></li>
#           <li class="gnb_category_reservations"><a href="https://www.hanbit.co.kr/store/books/reservations_list.html">예약도서</a></li> -->
#         </ul>
#       </ul>
#       <!--/li-->
#       <!--/ul-->
#
#       <ul class="lnb_depth1">
#         <li><a href="https://www.hanbit.co.kr/store/books/new_book_list.html">새로나온책</a></li><span>l</span>
#         <li><a href="https://www.hanbit.co.kr/store/books/reservations_list.html">예약도서</a></li><span>l</span>
#         <li><a href="https://www.hanbit.co.kr/store/books/bestseller_list.html">베스트셀러</a></li><span>l</span>
#         <li><a href="https://www.hanbit.co.kr/store/books/full_book_list.html">전체도서목록</a></li><span>l</span>
#         <li><a href="https://www.hanbit.co.kr/store/books/series_list.html">시리즈</a></li>
#         <!-- <li><a href="https://www.hanbit.co.kr/store/education/edu_list.html">교육</a></li><span>l</span>
#         <li><a href="https://www.hanbit.co.kr/store/item/item_list.html">Item &amp; Maker Shed</a></li> -->
#       </ul>
#
#       <!-- SUPPORT -->
#           </div>
#     </div>
#     <!--// lnb -->
#   </div>
# </header>
# <!-- //header -->
#
# <!-- 메인 검색 및 카테고리 영역 -->
# <div id="main_search_area" class="fixed" style="display:none;">
#   <div class="msa_wrap">
#
#     <!-- 검색 -->
#     <div class="msa_srch_wrap">
#       <form onsubmit="return false;">
#       <fieldset class="msa_srch_field">
#         <legend>한빛출판네트워크 검색</legend>
#         <input title="검색어" autocomplete="off" class="srch_keyword" accesskey="s" type="text" name="keyword_str" id="keyword_str" v-model="keyword" @input="typeKeyword">
#         <input type="submit" class="srch_btn" style="cursor:pointer;" @click="clickSearch">
#       </fieldset>
#       </form>
#     </div>
#     <!-- //검색 -->
#
#     <!-- ① 인기검색어 -->
#     <div class="msa_srch_polular" v-if="showPopularKeyword === true">
#       <h2 class="tit">인기 검색어 <span>(최근 1개월간)</span></h2>
#         <div class="popula_box">
#           <ul class="left">
#             <li v-for="keyword in leftPopularKeywordList">
#               <a :class="keyword.bold" @click="clickPopularKeyword(keyword)">
#                   {{ keyword.number }} {{ keyword.bookName }}
#               </a>
#             </li>
#           </ul>
#           <ul class="right">
#             <li v-for="keyword in rightPopularKeywordList">
#               <a :class="keyword.bold" @click="clickPopularKeyword(keyword)">
#                   {{ keyword.number }} {{ keyword.bookName }}
#               </a>
#             </li>
#           </ul>
#         </div>
#     </div>
#     <!-- ① 인기검색어 -->
#
#     <!-- ② 검색결과/검색서제스쳔 -->
#     <div class="msa_srch_suggestion" v-if="showPopularKeyword === false">
#       <div class="sugg_left" v-if="bookList.length !== 0">
#         <h3 class="tit">BOOK</h3>
#         <ul class="books_list">
#           <li v-for="book in bookList" @mouseover="mouseOverBook(book.id)"><a @click="clickBookKeyword(book)"><p v-html="book.name"></p></a></li>
#         </ul>
#       </div>
#
#       <div class="sugg_right">
#         <div class="sugg_book" v-if="bookList.length !== 0">
#           <table class="sugg_book_detail">
#             <tr>
#               <td class="cover">
#                 <a @click="clickBookKeyword(bookSummary)">
#                   <img :src="bookSummary.imgUrl" class="b_cover">
#                 </a>
#               </td>
#               <td class="draft">
#                 <a @click="clickBookKeyword(bookSummary)" class="b_title"><strong v-html="bookSummary.originName"></strong></a>
#                 <p class="b_int">
#                 {{ bookSummary.author }} 지음<br />
#                 {{ bookSummary.publishingCompany }} | {{ bookSummary.date }}
#                 </p>
#                 <p class="b_type">
#                 <span>{{ bookSummary.bookType }}</span>
#                 </p>
#               </td>
#             </tr>
#           </table>
#         </div>
#
#         <!--
#         <div class="sugg_edu" v-if="educationList.length !== 0">
#           <h3 class="tit">EDUCATION</h3>
#           <ul class="edu_list">
#             <li v-for="education in educationList">&#149; <a @click="clickEducationKeyword(education)"><span v-html="education.title"></span></a></li>
#           </ul>
#         </div>
#         -->
#
#         <div class="sugg_cont" v-if="contentList.length !== 0">
#           <h3 class="tit">CONTENTS</h3>
#           <ul class="cont_list">
#             <li v-for="content in contentList">&#149; <a @click="clickContentKeyword(content)"><span v-html="content.title"></span></a></li>
#           </ul>
#         </div>
#       </div>
#     </div>
#     <!-- //② 검색결과/검색서제스쳔 -->
#
#   <!-- 닫기 -->
#   <div class="msa_wrap_close">
#     <a href="javascript:;" onclick="view_hover('main_search_area','','hide')">닫기</a>
#   </div>
#   <!-- //닫기 -->
#
#   </div>
# </div>
#
# <script type="text/javascript">
#     "use strict";
#
#     var common_top_search_vue = new Vue({
#         el: '#main_search_area',
#         data: {
#             //검색엔진 URL
#             searchProxyURL: "https://search.hanbit.co.kr",
#             //인기 검색어 show 여부
#             showPopularKeyword: true,
#             //사용자 검색 키워드
#             keyword: '',
#             //인기 검색어 리스트
#             popularKeywordList: [],
#             // 인기 검색어 리스트 (왼쪽)
#             leftPopularKeywordList: [],
#             // 인기 검색어 리스트 (오른쪽)
#             rightPopularKeywordList: [],
#             // 자동완성에서의 책 리스트
#             bookList: [],
#             // 자동완성에서의 책 정보
#             bookSummary: {
#                 'imgUrl': '',
#                 'link': '',
#                 'name': '',
#                 'author': '',
#                 'publishingCompany': '',
#                 'date': '',
#                 'bookType': ''
#             },
#             //에듀케이션 리스트
#             educationList: [],
#             //컨텐츠 리스트
#             contentList: []
#         },
#         created: function created() {
#             // 인기 검색어 조회
#             this.getPopularKeyword();
#         },
#         methods: {
#             /**
#              * 사용자가 검색 키워드를 입력할때 발생하는 이벤트
#              */
#             typeKeyword: function typeKeyword() {
#                 var self = this;
#                 var keyword = $("#keyword_str").val();
#
#                 if (keyword.length !== 0) {
#                     //자동완성어
#                     this.findAutocompleteResult(keyword);
#                 } else {
#                     //인기검색어
#                     self.showPopularKeyword = true;
#                 }
#             },
#
#             /**
#              * 인기검색어 조회
#              */
#             getPopularKeyword: function getPopularKeyword() {
#                 var self = this;
#                 this.popularKeywordList = [];
#                 $.get(this.searchProxyURL + "/querylog/popularKeyword").done(function (data) {
#                     if (data != null) {
#                         self.drawPopularKeyword(data);
#                     }
#                 });
#             },
#
#             /**
#              * 인기 검색어 그리기
#              */
#             drawPopularKeyword: function drawPopularKeyword(popularBooks) {
#                 var self = this;
#                 popularBooks.forEach(function (item) {
#                     var popularBook = {
#                         bookName: item.keyword
#                     };
#                     self.popularKeywordList.push(popularBook);
#                 });
#                 var number = 0;
#
#                 for (var _iterator = this.popularKeywordList, _isArray = Array.isArray(_iterator), _i = 0, _iterator = _isArray ? _iterator : _iterator[Symbol.iterator]();;) {
#                     var _ref;
#
#                     if (_isArray) {
#                         if (_i >= _iterator.length) break;
#                         _ref = _iterator[_i++];
#                     } else {
#                         _i = _iterator.next();
#                         if (_i.done) break;
#                         _ref = _i.value;
#                     }
#
#                     var keyword = _ref;
#                     number = number + 1;
#                     keyword.number = number.toString().length < 2 ? "0" + number : number;
#
#                     if (number > 5) {
#                         keyword.direction = "right";
#                         self.rightPopularKeywordList.push(keyword);
#                     } else {
#                         keyword.direction = "left";
#
#                         if (number < 4) {
#                             keyword.bold = 'active';
#                         }
#
#                         self.leftPopularKeywordList.push(keyword);
#                     }
#                 }
#             },
#
#             /**
#              * 자동완성 검색 결과
#              */
#             findAutocompleteResult: function findAutocompleteResult(keyword) {
#                 var self = this;
#                 var param = {
#                     q: keyword,
#                     types: "education,book,contents",
#                     fq: keyword
#                 };
#                 $.post(this.searchProxyURL + "/autocomplete/search", param).done(function (data) {
#                     if (data != null) {
#                         var bookResult = data.booksResults;
#                         self.changeBookList(keyword, bookResult);
#                         var contentResult = data.contentsResults;
#                         self.changeContentList(keyword, contentResult);
#                         var educationResult = data.educationResults;
#                         self.changeEducationList(keyword, educationResult);
#                     }
#                 });
#                 this.showPopularKeyword = false;
#             },
#
#             /**
#              * 자동완성어에서 BOOK 부분에서 마우스를 올렸을 시에 발생하는 이벤트
#              * @param bookId
#              */
#             mouseOverBook: function mouseOverBook(bookId) {
#                 var currentBook = this.bookList.filter(function (book) {
#                     return book.id === bookId;
#                 });
#                 this.changeBookSummary(currentBook[0]);
#             },
#
#             /**
#              * 책 소개 변경
#              * @param book
#              */
#             changeBookSummary: function changeBookSummary(book) {
#                 if (book !== {}) {
#                     this.bookSummary.name = book.name;
#                     this.bookSummary.originName = book.originName;
#                     this.bookSummary.author = book.author;
#                     this.bookSummary.bookType = book.bookType;
#                     this.bookSummary.imgUrl = book.imgUrl;
#                     this.bookSummary.link = book.link;
#                     this.bookSummary.publishingCompany = book.publishingCompany;
#                     this.bookSummary.date = book.date;
#                     this.bookSummary.bookType = book.bookType;
#                 }
#             },
#
#             /**
#              * BOOK 리스트 변경
#              */
#             changeBookList: function changeBookList(keyword, bookResultList) {
#                 var self = this;
#                 self.bookList = [];
#                 var index = 0;
#
#                 if (bookResultList != null) {
#                     for (var _iterator2 = bookResultList, _isArray2 = Array.isArray(_iterator2), _i2 = 0, _iterator2 = _isArray2 ? _iterator2 : _iterator2[Symbol.iterator]();;) {
#                         var _ref2;
#
#                         if (_isArray2) {
#                             if (_i2 >= _iterator2.length) break;
#                             _ref2 = _iterator2[_i2++];
#                         } else {
#                             _i2 = _iterator2.next();
#                             if (_i2.done) break;
#                             _ref2 = _i2.value;
#                         }
#
#                         var result = _ref2;
#
#                         if (index < 10) {
#                             var book = {};
#                             book.id = result.code;
#                             book.originName = result.title;
#                             book.name = JSON.parse(JSON.stringify(self.replaceHighlightWord(result.title, keyword)));
#                             book.link = result.code;
#                             book.imgUrl = self.getBookImageURL(result.code);
#                             book.author = result.author;
#                             book.publishingCompany = result.brand;
#                             book.date = result.pubDate;
#                             book.bookType = result.bookType;
#                             self.bookList.push(book); //책 미리보기 변경
#
#                             self.changeBookSummary(self.bookList[0]);
#                         }
#                     }
#                 } else {
#                     self.initBookSummary();
#                 }
#             },
#
#             /**
#              * 책 이미지 주소 가져오기
#              */
#             getBookImageURL: function getBookImageURL(bookCode) {
#                 var imgURL;
#
#                 if (bookCode.substr(0, 1) === "E") {
#                     imgURL = '/data/ebook/' + bookCode + '_m.jpg';
#                 } else {
#                     imgURL = '/data/books/' + bookCode + "_m.jpg";
#                 }
#
#                 return imgURL;
#             },
#
#             /**
#              * 검색 결과가 없을 경우 책 미리보기 초기화
#              */
#             initBookSummary: function initBookSummary() {
#                 this.bookSummary = {
#                     'imgUrl': '',
#                     'link': '',
#                     'name': '',
#                     'author': '',
#                     'publishingCompany': '',
#                     'date': '',
#                     'bookType': ''
#                 };
#             },
#
#             /**
#              * education 리스트 변경
#              */
#             changeEducationList: function changeEducationList(keyword, educationResultList) {
#                 var self = this;
#                 self.educationList = [];
#                 var index = 0;
#
#                 if (educationResultList != null) {
#                     for (var _iterator3 = educationResultList, _isArray3 = Array.isArray(_iterator3), _i3 = 0, _iterator3 = _isArray3 ? _iterator3 : _iterator3[Symbol.iterator]();;) {
#                         var _ref3;
#
#                         if (_isArray3) {
#                             if (_i3 >= _iterator3.length) break;
#                             _ref3 = _iterator3[_i3++];
#                         } else {
#                             _i3 = _iterator3.next();
#                             if (_i3.done) break;
#                             _ref3 = _i3.value;
#                         }
#
#                         var result = _ref3;
#
#                         if (index < 3) {
#                             var content = {};
#                             content.title = JSON.parse(JSON.stringify(self.replaceHighlightWord(result.title, keyword)));
#                             content.link = result.code;
#                             self.educationList.push(content);
#                             index = index + 1;
#                         }
#                     }
#                 }
#             },
#
#             /**
#              * contents 리스트 변경
#              */
#             changeContentList: function changeContentList(keyword, contentResult) {
#                 var self = this;
#                 self.contentList = [];
#                 var index = 0;
#
#                 if (contentResult != null) {
#                     for (var _iterator4 = contentResult, _isArray4 = Array.isArray(_iterator4), _i4 = 0, _iterator4 = _isArray4 ? _iterator4 : _iterator4[Symbol.iterator]();;) {
#                         var _ref4;
#
#                         if (_isArray4) {
#                             if (_i4 >= _iterator4.length) break;
#                             _ref4 = _iterator4[_i4++];
#                         } else {
#                             _i4 = _iterator4.next();
#                             if (_i4.done) break;
#                             _ref4 = _i4.value;
#                         }
#
#                         var result = _ref4;
#
#                         if (index < 7) {
#                             var content = {};
#                             content.title = JSON.parse(JSON.stringify(self.replaceHighlightWord(result.title, keyword)));
#                             content.link = result.code;
#                             self.contentList.push(content);
#                             index = index + 1;
#                         }
#                     }
#                 }
#             },
#
#             /**
#              * 하이라이트 표시
#              */
#             replaceHighlightWord: function replaceHighlightWord(str, highlightKeyword) {
#                 var replaceHighlightKeyword = highlightKeyword.replace(/[^a-z0-9가-힣_ ]/gi, '');
#                 var regEx = new RegExp(replaceHighlightKeyword, "gi");
#                 str = str.replace(regEx, function (a) {
#                     return '<span class="keysel">' + a + '</span>';
#                 });
#                 return str;
#             },
#
#             /**
#              * 검색 버튼 클릭 시
#              * @param e
#              */
#             clickSearch: function clickSearch(e) {
#                 if (!this.keyword || this.keyword.length === 0) {
#                     alert("검색어를 입력하세요");
#                     $("#keyword_str").focus();
#                     e.preventDefault();
#                 } else {
#                     location.href = "/search/search_list.html?keyword=" + this.keyword;
#                 }
#             },
#
#             /**
#              * 인기 검색어 클릭시
#              * @param book
#              */
#             clickPopularKeyword: function clickPopularKeyword(book) {
#                 var searchKeyword = book.bookName;
#                 location.href = "/search/search_list.html?keyword=" + searchKeyword;
#             },
#
#             /**
#              * 책 검색어 클릭시 책 상세로 이동
#              * @param book
#              */
#             clickBookKeyword: function clickBookKeyword(book) {
#                 location.href = "/store/books/look.php?p_code=" + book.link;
#             },
#
#             /**
#              * 교육 클릭시 교육 상세로 이동
#              * @param education
#              */
#             clickEducationKeyword: function clickEducationKeyword(education) {
#                 location.href = "/store/education/edu_view.html?p_code=" + education.link;
#             },
#
#             /**
#              * 컨텐츠 클릭시 컨텐츠 상세로 이동
#              * @param contents
#              */
#             clickContentKeyword: function clickContentKeyword(content) {
#                 location.href = "/channel/category/category_view.html?cms_code=" + content.link;
#             }
#         }
#     });
# </script>
# <!-- //메인 검색 및 카테고리 영역 -->
#
# <!-- Contents -->
# <div id="container">
# 	<div class="docu_title">
# 		<h2>전체도서목록</h2>
# 	</div>
#
# 	<!-- 전체도서목록 wrap -->
# 	<div class="full_book_list_wrap">
# 		<!-- 브랜드 정렬 버튼 -->
#
#         <div class="btn_brand_area">
# 			<ul>
# 				<li class="curr">
#                 	<a href="/store/books/full_book_list.html">
#                     	                    <span class="name_full">전체</span>
#                                         </a>
#
#                 </li>
# 				<li >
# 					<a href="/store/books/full_book_list.html?brand=HM">
#                                         	<span class="name_abbr">M</span>
#                     					</a>
# 				</li>
#
# 				<li >
#                 	<a href="/store/books/full_book_list.html?brand=HA">
#                                         	<span class="name_abbr">A</span>
#                     					</a>
#                 </li>
# 				<li >
#                 	<a href="/store/books/full_book_list.html?brand=HB">
#                                         	<span class="name_abbr">B</span>
#                     					</a>
#                 </li>
# 				<li >
#                 	<a href="/store/books/full_book_list.html?brand=HL">
#                                         	<span class="name_abbr">L</span>
#                     					</a>
#                 </li>
# 				<li >
#                 	<a href="/store/books/full_book_list.html?brand=HE">
#                                         	<span class="name_abbr">E</span>
#                     					</a>
#                 </li>
# 				<!-- <li >
#                 	<a href="/store/books/full_book_list.html?brand=HR">
#                                         	<span class="name_abbr">R</span>
#                     					</a>
#                 </li>
# 				<li >
#                 	<a href="/store/books/full_book_list.html?brand=MK">
#                                         	<span class="name_abbr">MK</span>
#                     					</a>
#                 </li> -->
#
# 			</ul>
# 		</div>
#
#
#
# 		<!-- //브랜드 정렬 버튼 -->
#
# 		<!-- 출간일/도서명 순-->
# 		<div class="series_lineup">
# 			<ul>
# 				<li><a href="/store/books/full_book_list.html?srt=p_pub_date&brand="  class="curr" >출간일 순</a></li>
# 				<li><a href="/store/books/full_book_list.html?srt=p_title&brand=" >도서명 순</a></li>
# 			</ul>
# 		</div>
# 		<!-- //출간일/도서명 순-->
#
# 		<!-- 전체 목록 다운로드 버튼-->
# 		<div class="btn_full_list"><a href="javascript:document.frm.submit();">전체 목록 다운로드</a></div>
#
# 		<!-- 책 리스트 -->
# 		<div class="table_area">
# 			<table class="tbl_type_list" border="0" cellspacing="0" summary="전체목록 리스트 테이블">
# 				<caption>전체목록 리스트</caption>
# 				<colgroup>
# 				<col width="180px">
# 				<col width="">
# 				<col width="160px">
# 				<col width="134px">
# 				<col width="130px">
# 				</colgroup>
# 				<thead>
# 					<tr>
# 						<th scope="col">브랜드</th>
# 						<th scope="col">도서명</th>
# 						<th scope="col">저자</th>
# 						<th scope="col">발행일</th>
# 						<th scope="col">정가</th>
# 					</tr>
# 				</thead>
# 				<tbody>
# 									<tr>
# 						<td class="brd_m">한빛미디어</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B7974847632">리버스 엔지니어링 기드라 실전 가이드</a></td>
# 													<td class="left">나카지마 쇼타 외 3명  </td>
# 												<td>2022-01-10</td>
# 						<td class="right">50,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_l">한빛라이프</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B6205887122">초등 매일 독서의 힘</a></td>
# 													<td class="left">이은경   </td>
# 												<td>2022-01-10</td>
# 						<td class="right">17,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_m">한빛미디어</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B4035028569">맛있는 디자인 포토샵&일러스트레이터 CC 2022</a></td>
# 													<td class="left">빨간고래(박정아) 외 1명  </td>
# 												<td>2022-01-07</td>
# 						<td class="right">22,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_m">한빛미디어</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B9428200307">파워포인트 디자인 실무 강의 with 신프로</a></td>
# 													<td class="left">신프로(신강식)   </td>
# 												<td>2022-01-05</td>
# 						<td class="right">18,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_e">한빛에듀</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B1765707537">1학년 한글 떼기</a></td>
# 													<td class="left">하유정 외 1명  </td>
# 												<td>2022-01-05</td>
# 						<td class="right">12,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_a">한빛아카데미</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B1668287710">IT CookBook, C 언어 for Beginner 4판</a></td>
# 													<td class="left">우재남   </td>
# 												<td>2022-01-03</td>
# 						<td class="right">26,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_a">한빛아카데미</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B5199139984">IT CookBook, 파이썬 for Beginner&#40;3판&#41;</a></td>
# 													<td class="left">우재남   </td>
# 												<td>2022-01-03</td>
# 						<td class="right">25,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_a">한빛아카데미</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B1606660111">IT CookBook, 자바스크립트 프로그래밍 입문&#40;2판&#41;</a></td>
# 													<td class="left">윤인성   </td>
# 												<td>2022-01-03</td>
# 						<td class="right">27,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_m">한빛미디어</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B2913925878">SRE를 위한 시스템 설계와 구축</a></td>
# 													<td class="left">헤더 애드킨스 외 5명  </td>
# 												<td>2022-01-03</td>
# 						<td class="right">40,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_m">한빛미디어</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B6700696024">AI로 일하는 기술</a></td>
# 													<td class="left">장동인   </td>
# 												<td>2022-01-03</td>
# 						<td class="right">18,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_m">한빛미디어</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B8929106417">이것이 안드로이드다 with 코틀린&#40;3판&#41;</a></td>
# 													<td class="left">고돈호   </td>
# 												<td>2022-01-03</td>
# 						<td class="right">34,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_m">한빛미디어</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B1512470209">팀장부터 CEO까지 알아야 할 기업 정보보안 가이드</a></td>
# 													<td class="left">강은성   </td>
# 												<td>2022-01-03</td>
# 						<td class="right">25,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_a">한빛아카데미</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B7119209370">가상현실의 이해</a></td>
# 													<td class="left">송은지   </td>
# 												<td>2022-01-03</td>
# 						<td class="right">22,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_l">한빛라이프</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B1629132794">세밀화로 보는 멸종 동물 도감</a></td>
# 													<td class="left">라데크 말리 외 2명  </td>
# 												<td>2021-12-30</td>
# 						<td class="right">22,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_b">한빛비즈</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B9208153082">저는 주식투자가 처음인데요&#40;투자전략편 2022년 개정판&#41;</a></td>
# 													<td class="left">강병욱   </td>
# 												<td>2021-12-30</td>
# 						<td class="right">18,500원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_m">한빛미디어</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B2331794765">금융 전략을 위한 머신러닝</a></td>
# 													<td class="left">하리옴 탓샛 외 2명  </td>
# 												<td>2021-12-27</td>
# 						<td class="right">35,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_a">한빛아카데미</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B1836224274">STEM CookBook, 컴퓨팅 사고력을 키우는 이산수학&#40;3판&#41;</a></td>
# 													<td class="left">박주미   </td>
# 												<td>2021-12-26</td>
# 						<td class="right">29,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_m">한빛미디어</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B2009421115">그래프QL 인 액션</a></td>
# 													<td class="left">사메르 부나   </td>
# 												<td>2021-12-24</td>
# 						<td class="right">35,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_m">한빛미디어</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B6566099029">비전 시스템을 위한 딥러닝</a></td>
# 													<td class="left">모하메드 엘겐디   </td>
# 												<td>2021-12-20</td>
# 						<td class="right">38,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_m">한빛미디어</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B8356303939">무던한 개발자를 위한 모던한 자바스크립트</a></td>
# 													<td class="left">카이 호스트만   </td>
# 												<td>2021-12-20</td>
# 						<td class="right">32,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_m">한빛미디어</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B9115831934">소문난 명강의 : 오준석의 안드로이드 생존코딩_코틀린 편&#40;2판&#41;</a></td>
# 													<td class="left">오준석   </td>
# 												<td>2021-12-17</td>
# 						<td class="right">32,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_l">한빛라이프</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B6694310162">하루 한 장 초등과학 365</a></td>
# 													<td class="left">치바 가즈요시   </td>
# 												<td>2021-12-14</td>
# 						<td class="right">19,800원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_b">한빛비즈</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B6972407557">다시, 배우다</a></td>
# 													<td class="left">폴 김   </td>
# 												<td>2021-12-10</td>
# 						<td class="right">16,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_m">한빛미디어</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B3128413784">당당한 디자인 결정을 위한 9가지 방법</a></td>
# 													<td class="left">톰 그리버   </td>
# 												<td>2021-12-10</td>
# 						<td class="right">22,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_b">한빛비즈</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B3079611842">슈퍼 석세스</a></td>
# 													<td class="left">댄 페냐   </td>
# 												<td>2021-12-03</td>
# 						<td class="right">25,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_l">한빛라이프</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B5051207171">365 부모 말하기 연습 일력&#40;스프링북&#41;</a></td>
# 													<td class="left">박재연 외 1명  </td>
# 												<td>2021-12-01</td>
# 						<td class="right">18,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_m">한빛미디어</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B9849681760">엑셀 매크로&VBA 업무 공략집</a></td>
# 													<td class="left">최준선   </td>
# 												<td>2021-11-30</td>
# 						<td class="right">22,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_a">한빛아카데미</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B2369847218">공학도를 위한 수치해석&#40;8판&#41;</a></td>
# 													<td class="left">Steven C.Chapra 외 1명  </td>
# 												<td>2021-11-30</td>
# 						<td class="right">36,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_m">한빛미디어</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B5522056035">데이터 과학자 되는 법</a></td>
# 													<td class="left">에밀리 로빈슨 외 1명  </td>
# 												<td>2021-11-26</td>
# 						<td class="right">24,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_b">한빛비즈</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B2065798525">돈 되는 기획</a></td>
# 													<td class="left">김도균   </td>
# 												<td>2021-11-26</td>
# 						<td class="right">14,500원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_l">한빛라이프</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B9846994455">초등 어휘력이 공부력이다</a></td>
# 													<td class="left">박명선   </td>
# 												<td>2021-11-25</td>
# 						<td class="right">18,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_m">한빛미디어</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B4760409086">빠르게 찾아 바로 적용하는 엑셀 에센스 사전 100</a></td>
# 													<td class="left">한은숙   </td>
# 												<td>2021-11-25</td>
# 						<td class="right">18,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_m">한빛미디어</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B8065152313">스토리텔링 우동이즘의 잘 팔리는 웹툰, 웹소설 이야기 만들기</a></td>
# 													<td class="left">우동이즘(이동우)   </td>
# 												<td>2021-11-15</td>
# 						<td class="right">16,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_b">한빛비즈</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B4323864133">만화로 배우는 의학의 역사&#40;개정판&#41;</a></td>
# 													<td class="left">장 노엘 파비아니 외 3명  </td>
# 												<td>2021-11-15</td>
# 						<td class="right">20,800원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_l">한빛라이프</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B6708526662">중학교 입학 가이드</a></td>
# 													<td class="left">배혜림   </td>
# 												<td>2021-11-11</td>
# 						<td class="right">16,500원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_b">한빛비즈</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B7543250605">비겁한 돈</a></td>
# 													<td class="left">황현희 외 1명  </td>
# 												<td>2021-11-08</td>
# 						<td class="right">16,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_m">한빛미디어</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B9271409344">보고서 작성 실무 강의&#40;개정판&#41;</a></td>
# 													<td class="left">홍장표   </td>
# 												<td>2021-11-08</td>
# 						<td class="right">18,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_l">한빛라이프</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B7414861642">나도 영문 손글씨 잘 쓰면 소원이 없겠네</a></td>
# 													<td class="left">윤정희(리제 캘리그라피)   </td>
# 												<td>2021-11-05</td>
# 						<td class="right">16,800원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_m">한빛미디어</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B2201215526">구글 BERT의 정석</a></td>
# 													<td class="left">수다르산 라비찬디란   </td>
# 												<td>2021-11-03</td>
# 						<td class="right">34,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_e">한빛에듀</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B8817853747">1000개 숨은그림찾기 보물찾기 : 찾아도 찾아도 끝판왕</a></td>
# 													<td class="left">전진희   </td>
# 												<td>2021-11-02</td>
# 						<td class="right">8,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_e">한빛에듀</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B5962335045">1000개 숨은그림찾기 탈것 : 찾아도 찾아도 끝판왕</a></td>
# 													<td class="left">이한이   </td>
# 												<td>2021-11-02</td>
# 						<td class="right">8,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_e">한빛에듀</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B2186305189">1000개 숨은그림찾기 몬스터 : 찾아도 찾아도 끝판왕</a></td>
# 													<td class="left">김확실   </td>
# 												<td>2021-11-02</td>
# 						<td class="right">8,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_m">한빛미디어</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B3931996053">머신러닝 디자인 패턴</a></td>
# 													<td class="left">발리아파 락슈마난 외 2명  </td>
# 												<td>2021-11-01</td>
# 						<td class="right">38,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_m">한빛미디어</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B1494466807">소프트웨어 아키텍처 101</a></td>
# 													<td class="left">마크 리처즈 외 1명  </td>
# 												<td>2021-11-01</td>
# 						<td class="right">32,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_m">한빛미디어</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B6846155853">혼자 공부하는 SQL</a></td>
# 													<td class="left">우재남   </td>
# 												<td>2021-11-01</td>
# 						<td class="right">24,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_m">한빛미디어</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B7944573971">UX/UI 디자이너를 위한 실무 피그마</a></td>
# 													<td class="left">클레어 정   </td>
# 												<td>2021-11-01</td>
# 						<td class="right">24,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_a">한빛아카데미</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B1041700089">IT CookBook, 그림으로 배우고 실생활 예제로 실습하는 자바를 부탁해</a></td>
# 													<td class="left">박세홍(홍팍)   </td>
# 												<td>2021-10-29</td>
# 						<td class="right">26,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_a">한빛아카데미</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B5160362412">온톨로지 과학자를 위한 지식그래프</a></td>
# 													<td class="left">딘 알레망 외 2명  </td>
# 												<td>2021-10-29</td>
# 						<td class="right">45,000원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_e">한빛에듀</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B4258054769">똑똑한 두뇌 연습 : 놀이공원 미로찾기</a></td>
# 													<td class="left">권나영   </td>
# 												<td>2021-10-28</td>
# 						<td class="right">7,500원</td>
# 					</tr>
#
# 										<tr>
# 						<td class="brd_m">한빛미디어</td>
# 						<td class="left"><a href="/store/books/look.php?p_code=B9275242581">한 권으로 다지는 머신러닝&딥러닝 with 파이썬</a></td>
# 													<td class="left">알베르토 아르타산체스 외 1명  </td>
# 												<td>2021-10-21</td>
# 						<td class="right">40,000원</td>
# 					</tr>
#
#
# 				</tbody>
# 			</table>
# 		</div>
# 		<!-- //책 리스트 -->
#
# 		<!-- 페이징 -->
# 		<div class="paginate bdr_no">
# 			<strong>1</strong>
# <a href="/store/books/full_book_list.html?page=2&srt=p_pub_date&brand=">2</a>
# <a href="/store/books/full_book_list.html?page=3&srt=p_pub_date&brand=">3</a>
# <a href="/store/books/full_book_list.html?page=4&srt=p_pub_date&brand=">4</a>
# <a href="/store/books/full_book_list.html?page=5&srt=p_pub_date&brand=">5</a>
# <a href="/store/books/full_book_list.html?page=6&srt=p_pub_date&brand=">6</a>
# <a href="/store/books/full_book_list.html?page=7&srt=p_pub_date&brand=">7</a>
# <a href="/store/books/full_book_list.html?page=8&srt=p_pub_date&brand=">8</a>
# <a href="/store/books/full_book_list.html?page=9&srt=p_pub_date&brand=">9</a>
# <a href="/store/books/full_book_list.html?page=10&srt=p_pub_date&brand=">10</a>
# <a href="/store/books/full_book_list.html?page=11&srt=p_pub_date&brand=" class="next"><span>&gt;</span></a>
# 		</div>
# 		<!-- //페이징 -->
#
# 		<!-- 전체 목록 다운로드 버튼-->
# 		<div class="btn_full_list mt40"><a href="javascript:document.frm.submit();">전체 목록 다운로드</a></div>
#
# 	</div>
# 	<!-- //전체도서목록 wrap -->
#
# </div>
# <!-- //Contents -->
# <form name="frm" id="frm" method="post" action="./full_book_list_down.php">
# <input type="hidden" name="brand" id="brand" value="">
# <input type="hidden" name="srt" id="srt" value="p_pub_date">
# </form>
# <!-- Footer -->
# <footer>
#   <!-- 공지사항 -->
#   <div class="foot_notice" style="height:6px;"></div>  <!-- //공지사항 -->
#
#   <div class="foot_contents">
#     <!-- 하단 메뉴 -->
#     <div class="foot_menu">
#       <!-- added by coffin -->
#             <ul>
#         <li><a href="https://www.hanbit.co.kr/publisher/index.html" target="_blank">회사소개</a>(<a href="https://www.hanbit.co.kr/publisher/index.html" target="_blank">KOR</a> | <a href="https://www.hanbit.co.kr/publisher/index.html?lang=e" target="_blank">ENG</a>) &#149; <a href="https://www.hanbit.co.kr/publisher/contact.html?lang=k" target="_blank">약도</a></li>
#         <li><a href="https://www.hanbit.co.kr/publisher/write.html" target="_blank">기획 및 원고 모집</a></li>
#         <li><a href="https://www.hanbit.co.kr/publisher/career.html" target="_blank">채용</a> &#149; 입사지원 <a href="mailto:jobs@hanbit.co.kr">jobs@hanbit.co.kr</a></li>
#         <li><a href="https://www.hanbit.co.kr/publisher/foreignrights.html" target="_blank">FOREIGN RIGHTS</a></li>
#         <li><a href="https://www.hanbit.co.kr/member/use_agreement.html">이용약관</a> &#149; <a href="https://www.hanbit.co.kr/member/privacy_policy.html"><strong>개인정보처리방침</strong></a></li>
#         <li><a href="https://www.hanbit.co.kr/sitemap/sitemap.html">사이트맵</a></li>
#       </ul>
#           </div>
#     <!-- //하단 메뉴 -->
#
#     <!-- SNS -->
#     <div class="foot_sns">
#
#       <ul>
#         <li class="foot_facebook"><a href="https://www.facebook.com/hanbitmedia" target="_blank"><span>페이스북</span></a></li>
#         <!-- <li class="foot_googleplus"><a href="https://plus.google.com/u/0/+HanbitCoKr/posts" target="_blank"><span>구글플러스</span></a></li> -->
#         <!-- <li class="foot_twitter"><a href="https://twitter.com/hanbit" target="_blank"><span>트위터</span></a></li> -->
#         <li class="foot_youtube"><a href="https://www.youtube.com/한빛TV" target="_blank"><span>유튜브</span></a></li>
#         <li class="foot_bolg"><a href="http://blog.hanbit.co.kr/" target="_blank"><span>블로그</span></a></li>
#         <li class="foot_naverpost"><a href="https://m.post.naver.com/hanbitstory" target="_blank"><span>네이버포스트</span></a></li>
#       </ul>
#
#
#         <fieldset class="foot_srch">
#           <legend>하단 검색영역</legend>
#           <input title="검색어" class="foot_srch_keyword" accesskey="s" type="text" value=""  id="foot_keyword_str" style="font-size:16px;">
#           <input type="button" alt="" class="foot_srch_btn" onclick="foot_sch_smit();" style="cursor: pointer;">
#         </fieldset>
#
#
#       <script>
#         // 검색 리스트
#         $(document).ready(function() {
#           $('#foot_keyword_str').keyup(function(e) {
#             if (e.keyCode == 13)
#               foot_sch_smit();
#           });
#         });
#
#         function foot_sch_smit(){
#           var foot_keyword_str = $("#foot_keyword_str").val();
#           var searchUrl = "/search/search_list.html?keyword="+foot_keyword_str;
#
#           if(!foot_keyword_str){
#             alert("검색어를 입력해주세요");
#             $("#foot_keyword_str").focus();
#           }else{
#             location.href = searchUrl;
#           }
#         }
#       </script>
#
#     </div>
#     <!-- //SNS -->
#
#     <!-- 한빛 정보 -->
#     <div class="foot_about">
#       <div class="foot_about_area">
#
#
#         <p><strong>한빛미디어㈜ &#149; 한빛아카데미㈜ &#149; 한빛비즈㈜</strong></p>
#         <p>(03785) 서울 서대문구 연희로2길 62</p>
#         <p>EMAIL : support@hanbit.co.kr</p>
#         <p>대표이사 : 김태헌</p>
#         <p>사업자등록번호 : 220-81-05665 <a href="http://www.ftc.go.kr/bizCommPop.do?wrkr_no=2208105665" target="_blank">[확인]</a></p>
#         <p>통신판매업신고 : 2017-서울서대문-0671호</p>
#         <p>호스팅제공자 : (주)누리호스팅</p>
#
#       </div>
#     </div>
#     <!-- //한빛 정보 -->
#   </div>
#
#   <div class="copyright">&copy;1993-2022 Hanbit Publishing Network, Inc. All rights reserved.</div>
# </footer>
# <!-- //푸터 -->
# <div class="foot_download_btn"><a href="https://www.hanbit.co.kr/support/supplement_list.html">자료실</a></div>
#
# <!-- 공통 JS 호출 -->
# <script type="text/javascript" src="/js/common.js"></script>
# <!-- //공통 JS 호출 -->
#
# </body>
# </html>

# %%
html_file = open('dp.html', 'w')
html_file.write(text_html)
html_file.close()

# %% [markdown]
# # ch2.5 스크래핑한 웹 페이지에서 데이터 추출하기

# %% [markdown]
# ## ch2.5.1 정규 표현식으로 스크레이핑 하기

# %%
import re
from html import unescape

# 이전 절에서 다운로드한 파일을 열고 html이라는 변수에 저장합니다.
with open('dp.html') as f:
    html = f.read()
html
# Out:
# '<!DOCTYPE html>\n\n<html lang="ko">\n\n<head>\n\n<!--[if lte IE 8]>\n\n<script>\n\n  location.replace(\'/support/explorer_upgrade.html\');\n\n</script>\n\n<![endif]-->\n\n<meta charset="utf-8"/>\n\n<title>한빛출판네트워크</title>\n\n<link rel="shortcut icon" href="https://www.hanbit.co.kr/images/common/hanbit.ico"> \n\n<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n\n<meta property="og:type" content="website"/>\n\n<meta property="og:title" content="한빛출판네트워크"/>\n\n<meta property="og:description" content="더 넓은 세상, 더 나은 미래를 위한 아시아 출판 네트워크 :: 한빛미디어, 한빛아카데미, 한빛비즈, 한빛라이프, 한빛에듀"/>\n\n<meta property="og:image" content="https://www.hanbit.co.kr/images/hanbitpubnet_logo.jpg" />\n\n<meta property="og:url" content="https://www.hanbit.co.kr/store/books/full_book_list.html"/>\n\n<link rel="canonical" href="https://www.hanbit.co.kr/store/books/full_book_list.html" />\n\n<meta name="keywords" content="한빛미디어,한빛아카데미,한빛비즈,한빛라이프,한빛에듀,리얼타임,대관서비스,책,출판사,IT전문서,IT활용서,대학교재,경제경영,어린이/유아,실용/여행,전자책,자격증,교육,세미나,강의,ebook,정보교과서" />\n\n<meta name="description" content="더 넓은 세상, 더 나은 미래를 위한 아시아 출판 네트워크 :: 한빛미디어, 한빛아카데미, 한빛비즈, 한빛라이프, 한빛에듀" />\n\n<meta name="viewport" content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0">\n\n<meta name="viewport" content="width=1260">\n\n<meta name="apple-mobile-web-app-capable" content="yes" />\n\n<meta name="naver-site-verification" content="01c29ed1852aecca7a48ac0c3e0869627bc512d8"/>\n\n<link rel="stylesheet" href="/css/common.css?20210603093421" />\n\n<link href="/css/hover.css" rel="stylesheet" media="all">\n\n<link rel="stylesheet" href="/js/jquery.raty.css" />\n\n<script type="text/javascript" src="/js/jquery-latest.js"></script>\n\n<script type="text/javascript" src="/js/jquery-ui.js"></script>\n\n<script type="text/javascript" src="/js/jquery.event.drag-1.5.min.js"></script>\n\n<script type="text/javascript" src="/js/jquery.touchSlider.js"></script>\n\n<script type="text/javascript" src="/js/jquery.raty.js"></script>\n\n<script type="text/javascript" src="/js/main.js"></script>\n\n<script type="text/javascript" src="/lib/cheditor/cheditor.js"></script>\n\n<script type="text/javascript" src="/js/jquery.ui.datepicker-ko.js"></script>\n\n<script type="text/javascript" src="/js/engine.js"></script>\n\n<script type="text/javascript" src="/js/vue.js"></script>\n\n\n\n<!-- Google Analytics -->\n\n<script>\n\n(function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n\n(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n\nm=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n\n})(window,document,\'script\',\'//www.google-analytics.com/analytics.js\',\'ga\');\n\nga(\'create\', \'UA-47080738-1\', \'hanbit.co.kr\');\n\nga(\'require\', \'linkid\', \'linkid.js\');\n\nga(\'send\', \'pageview\');\n\n</script>\n\n<!-- Google Analytics -->\n\n\n\n<!-- Facebook Pixel Code -->\n\n<script>\n\n  !function(f,b,e,v,n,t,s)\n\n  {if(f.fbq)return;n=f.fbq=function(){n.callMethod?\n\n  n.callMethod.apply(n,arguments):n.queue.push(arguments)};\n\n  if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version=\'2.0\';\n\n  n.queue=[];t=b.createElement(e);t.async=!0;\n\n  t.src=v;s=b.getElementsByTagName(e)[0];\n\n  s.parentNode.insertBefore(t,s)}(window, document,\'script\',\n\n  \'https://connect.facebook.net/en_US/fbevents.js\');\n\n  fbq(\'init\', \'406459623338891\');\n\n  fbq(\'track\', \'PageView\');\n\n</script>\n\n<noscript><img height="1" width="1" style="display:none"\n\n  src="https://www.facebook.com/tr?id=406459623338891&ev=PageView&noscript=1"\n\n/></noscript>\n\n<!-- End Facebook Pixel Code -->\n\n\n\n<!-- Google Tag Manager -->\n\n<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n\nnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n\nj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n\n\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f); ...

# %%
# 크롤링가 스크레이핑 59쪽 
# re.findall()을 사용해 도서 하나에 해당하는 HTML을 추출합니다.
#re.DOTALL  옵션은 여러 줄로 이루어진 문자열에서 \n에 상관없이 검색할 때 많이 사용한다

for partial_html in re.findall('<td class="left"><a.*?</td>', html, re.DOTALL):
    # 도서의 URL을 추출합니다.
    url = re.search('<a href="(.*?)">', partial_html).group(1)
    url = 'http://www.hanbit.co.kr' + url
    # 태그를 제거해서 도서의 제목을 추출합니다.
    title = re.sub('<.*?>', '', partial_html) # <> <> 부분을 공백으로 변경 -> 타이틀 제목만 남음
    print(partial_html)
    title = unescape(title)
    print('url:', url)
    print('title:', title,'\n')
# Out:
# <td class="left"><a href="/store/books/look.php?p_code=B7974847632">리버스 엔지니어링 기드라 실전 가이드</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B7974847632
# title: 리버스 엔지니어링 기드라 실전 가이드
#
# <td class="left"><a href="/store/books/look.php?p_code=B6205887122">초등 매일 독서의 힘</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B6205887122
# title: 초등 매일 독서의 힘
#
# <td class="left"><a href="/store/books/look.php?p_code=B4035028569">맛있는 디자인 포토샵&일러스트레이터 CC 2022</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B4035028569
# title: 맛있는 디자인 포토샵&일러스트레이터 CC 2022
#
# <td class="left"><a href="/store/books/look.php?p_code=B9428200307">파워포인트 디자인 실무 강의 with 신프로</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B9428200307
# title: 파워포인트 디자인 실무 강의 with 신프로
#
# <td class="left"><a href="/store/books/look.php?p_code=B1765707537">1학년 한글 떼기</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B1765707537
# title: 1학년 한글 떼기
#
# <td class="left"><a href="/store/books/look.php?p_code=B1668287710">IT CookBook, C 언어 for Beginner 4판</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B1668287710
# title: IT CookBook, C 언어 for Beginner 4판
#
# <td class="left"><a href="/store/books/look.php?p_code=B5199139984">IT CookBook, 파이썬 for Beginner&#40;3판&#41;</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B5199139984
# title: IT CookBook, 파이썬 for Beginner(3판)
#
# <td class="left"><a href="/store/books/look.php?p_code=B1606660111">IT CookBook, 자바스크립트 프로그래밍 입문&#40;2판&#41;</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B1606660111
# title: IT CookBook, 자바스크립트 프로그래밍 입문(2판)
#
# <td class="left"><a href="/store/books/look.php?p_code=B2913925878">SRE를 위한 시스템 설계와 구축</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B2913925878
# title: SRE를 위한 시스템 설계와 구축
#
# <td class="left"><a href="/store/books/look.php?p_code=B6700696024">AI로 일하는 기술</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B6700696024
# title: AI로 일하는 기술
#
# <td class="left"><a href="/store/books/look.php?p_code=B8929106417">이것이 안드로이드다 with 코틀린&#40;3판&#41;</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B8929106417
# title: 이것이 안드로이드다 with 코틀린(3판)
#
# <td class="left"><a href="/store/books/look.php?p_code=B1512470209">팀장부터 CEO까지 알아야 할 기업 정보보안 가이드</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=
a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B9846994455
# title: 초등 어휘력이 공부력이다
#
# <td class="left"><a href="/store/books/look.php?p_code=B4760409086">빠르게 찾아 바로 적용하는 엑셀 에센스 사전 100</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B4760409086
# title: 빠르게 찾아 바로 적용하는 엑셀 에센스 사전 100
#
# <td class="left"><a href="/store/books/look.php?p_code=B8065152313">스토리텔링 우동이즘의 잘 팔리는 웹툰, 웹소설 이야기 만들기</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B8065152313
# title: 스토리텔링 우동이즘의 잘 팔리는 웹툰, 웹소설 이야기 만들기
#
# <td class="left"><a href="/store/books/look.php?p_code=B4323864133">만화로 배우는 의학의 역사&#40;개정판&#41;</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B4323864133
# title: 만화로 배우는 의학의 역사(개정판)
#
# <td class="left"><a href="/store/books/look.php?p_code=B6708526662">중학교 입학 가이드</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B6708526662
# title: 중학교 입학 가이드
#
# <td class="left"><a href="/store/books/look.php?p_code=B7543250605">비겁한 돈</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B7543250605
# title: 비겁한 돈
#
# <td class="left"><a href="/store/books/look.php?p_code=B9271409344">보고서 작성 실무 강의&#40;개정판&#41;</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B9271409344
# title: 보고서 작성 실무 강의(개정판)
#
# <td class="left"><a href="/store/books/look.php?p_code=B7414861642">나도 영문 손글씨 잘 쓰면 소원이 없겠네</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B7414861642
# title: 나도 영문 손글씨 잘 쓰면 소원이 없겠네
#
# <td class="left"><a href="/store/books/look.php?p_code=B2201215526">구글 BERT의 정석</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B2201215526
# title: 구글 BERT의 정석
#
# <td class="left"><a href="/store/books/look.php?p_code=B8817853747">1000개 숨은그림찾기 보물찾기 : 찾아도 찾아도 끝판왕</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B8817853747
# title: 1000개 숨은그림찾기 보물찾기 : 찾아도 찾아도 끝판왕
#
# <td class="left"><a href="/store/books/look.php?p_code=B5962335045">1000개 숨은그림찾기 탈것 : 찾아도 찾아도 끝판왕</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B5962335045
# title: 1000개 숨은그림찾기 탈것 : 찾아도 찾아도 끝판왕
#
# <td class="left"><a href="/store/books/look.php?p_code=B2186305189">1000개 숨은그림찾기 몬스터 : 찾아도 찾아도 끝판왕</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B2186305189
# title: 1000개 숨은그림찾기 몬스터 : 찾아도 찾아도 끝판왕
#
# <td class="left"><a href="/store/books/look.php?p_code=B3931996053">머신러닝 디자인 패턴</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B3931996053
# title: 머신러닝 디자인 패턴
#
# <td class="left"><a href="/store/books/look.php?p_code=B1494466807">소프트웨어 아키텍처 101</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B1494466807
# title: 소프트웨어 아키텍처 101
#
# <td class="left"><a href="/store/books/look.php?p_code=B6846155853">혼자 공부하는 SQL</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B6846155853
# title: 혼자 공부하는 SQL
#
# <td class="left"><a href="/store/books/look.php?p_code=B7944573971">UX/UI 디자이너를 위한 실무 피그마</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B7944573971
# title: UX/UI 디자이너를 위한 실무 피그마
#
# <td class="left"><a href="/store/books/look.php?p_code=B1041700089">IT CookBook, 그림으로 배우고 실생활 예제로 실습하는 자바를 부탁해</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B1041700089
# title: IT CookBook, 그림으로 배우고 실생활 예제로 실습하는 자바를 부탁해
#
# <td class="left"><a href="/store/books/look.php?p_code=B5160362412">온톨로지 과학자를 위한 지식그래프</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B5160362412
# title: 온톨로지 과학자를 위한 지식그래프
#
# <td class="left"><a href="/store/books/look.php?p_code=B4258054769">똑똑한 두뇌 연습 : 놀이공원 미로찾기</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B4258054769
# title: 똑똑한 두뇌 연습 : 놀이공원 미로찾기
#
# <td class="left"><a href="/store/books/look.php?p_code=B9275242581">한 권으로 다지는 머신러닝&딥러닝 with 파이썬</a></td>
# url: http://www.hanbit.co.kr/store/books/look.php?p_code=B9275242581
# title: 한 권으로 다지는 머신러닝&딥러닝 with 파이썬

# %% [markdown]
# ## ch2.5.2 XML(RSS) 스크레이핑 후 파싱하기

# %% [raw]
# # 서울/경기도 지역의 날씨
# https://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=109

# %%
import sys
from urllib.request import urlopen

# urlopen() 함수는 HTTPResponse 자료형의 객체를 반환합니다.
f = urlopen('https://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=109')
# bytes 자료형의 응답 본문을 일단 변수에 저장합니다.
bytes_content = f.read()  

# 추출한 인코딩으로 다시 디코딩합니다.
text_xml = bytes_content.decode('utf-8')
# 응답 본문을 표준 출력에 출력합니다.
print(text_xml)
# Out:
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_02.jsp</link>
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubDate>2022년 01월 05일 (수)요일 06:00</pubDate>
#  <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>서울,경기도 육상 중기예보 - 2022년 01월 05일 (수)요일 06:00 발표</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_02.jsp</link>
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_02.jsp</guid>
# <description>
# 	<header>
# 		<title>서울,경기도 육상중기예보</title>
# 		<tm>202201050600</tm>
# 		<wf><![CDATA[○ (기온) 8일(토)~10일(월) 아침 기온은 -8~-1도, 낮 기온은 2~6도로 어제(4일, 아침최저기온 -10~-3도, 낮최고기온 0~4도)보다 조금 높겠고,<br />          11일(화)~15일(토) 아침 기온은 -11~-2도, 낮 기온은 -2~3도로 어제와 비슷하거나 조금 낮겠습니다.      <br />○ (해상) 서해중부해상의 물결은 11일(화)은 1.0~2.5m, 그 밖의 날은 0.5~2.0m로 일겠습니다.<br />○ (주말전망) 8일(토)은 구름많겠고, 9일(일)은 흐리다가 오후에 구름많겠습니다. 아침 기온은 -8~-1도, 낮 기온은 3~6도가 되겠습니다. <br /><br />* 이번 예보기간에는 대기가 매우 건조하겠으니, 산불 등 각종 화재에 각별히 주의하기 바랍니다.]]></wf>
# 	</header>
# 	<body>
#
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>서울</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-1</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-14 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>인천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-1</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>-2</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>-2</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-14 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>수원</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-14 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>파주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-11</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-11</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-11</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-11</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-14 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>이천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-4</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-14 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>평택</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-1</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-14 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>백령도</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>2</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>2</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>0</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-14 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>과천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>-2</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>-2</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-14 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>광명</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>0</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>-3</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>-3</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-14 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>-2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>-2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>강화</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-4</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>-2</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>-2</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-14 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>-2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>김포</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-14 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>시흥</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>-2</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>-2</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-14 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>안산</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-1</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>-3</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>-3</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-14 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>부천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-1</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-14 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>-2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>의정부</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-11</tmn>
# 					<tmx>-2</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-11</tmn>
# 					<tmx>-2</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-14 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>고양</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-14 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>-2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>양주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-4</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-12</tmn>
# 					<tmx>-2</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-12</tmn>
# 					<tmx>-2</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-11</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-11</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-14 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-11</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>동두천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-11</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-11</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>3</tmx>
# ...
# 					<wf>구름많음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>의왕</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>-4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>-4</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-14 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>-2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>-2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>군포</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>0</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>-3</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>-3</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-14 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>-2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>-2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>안성</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-14 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>용인</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-14 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>광주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>-3</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>-3</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-14 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>-2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>-2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>여주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-08 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-09 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-10 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-11 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2022-01-12 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-14 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2022-01-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
#
#
#
# 	</body>
# </description>
# </item>
# </channel>
# </rss>

# %%
# 파일로 저장하기
xml_file = open('rss.xml', 'w',encoding = 'utf-8')
xml_file.write(text_xml)
xml_file.close()

# %% [markdown]
# ### ElementTree로 필요한 데이터만 추출하기

# %%
# ElementTree 모듈을 읽어 들입니다.
from xml.etree import ElementTree
import pandas as pd
tm_ef_list = []
tmn_list = []
tmx_list = []
wf_list = []
mo_de_list = []
# parse() 함수로 파일을 읽어 들이고 ElementTree 객체를 만듭니다.
tree = ElementTree.parse('rss.xml')

# getroot() 메서드로 XML의 루트 요소를 추출합니다.
root = tree.getroot()

# findall() 메서드로 요소 목록을 추출합니다.
# 태그를 찾습니다(자세한 내용은 RSS를 열어 참고해주세요).
for item in root.findall('channel/item/description/body/location/data'):
    # find() 메서드로 요소를 찾고 text 속성으로 값을 추출합니다.
    mo_de = item.find('mode').text
    tm_ef = item.find('tmEf').text
    tmn = item.find('tmn').text
    tmx = item.find('tmx').text
    wf = item.find('wf').text
    print(mo_de,tm_ef, tmn, tmx, wf) # 출력합니다.
    mo_de_list.append(mo_de)
    tm_ef_list.append(tm_ef)
    tmn_list.append(tmn)
    tmx_list.append(tmx)
    wf_list.append(wf)
    
df = pd.DataFrame({'mo_de':mo_de,'tm_ef':tm_ef_list, 'tmn':tmn_list, 'tmx':tmx_list, 'wf':wf_list})
# Out:
# A02 2022-01-08 00:00 -4 4 구름많음
# A02 2022-01-08 12:00 -4 4 구름많음
# A02 2022-01-09 00:00 -1 4 흐림
# A02 2022-01-09 12:00 -1 4 구름많음
# A02 2022-01-10 00:00 -4 3 구름많음
# A02 2022-01-10 12:00 -4 3 구름많음
# A02 2022-01-11 00:00 -8 -1 맑음
# A02 2022-01-11 12:00 -8 -1 맑음
# A02 2022-01-12 00:00 -7 1 맑음
# A02 2022-01-12 12:00 -7 1 맑음
# A01 2022-01-13 00:00 -4 3 구름많음
# A01 2022-01-14 00:00 -6 0 맑음
# A01 2022-01-15 00:00 -7 0 구름많음
# A02 2022-01-08 00:00 -3 5 구름많음
# A02 2022-01-08 12:00 -3 5 구름많음
# A02 2022-01-09 00:00 -1 3 흐림
# A02 2022-01-09 12:00 -1 3 구름많음
# A02 2022-01-10 00:00 -3 2 구름많음
# A02 2022-01-10 12:00 -3 2 구름많음
# A02 2022-01-11 00:00 -7 -2 맑음
# A02 2022-01-11 12:00 -7 -2 맑음
# A02 2022-01-12 00:00 -6 1 맑음
# A02 2022-01-12 12:00 -6 1 맑음
# A01 2022-01-13 00:00 -2 3 구름많음
# A01 2022-01-14 00:00 -4 0 맑음
# A01 2022-01-15 00:00 -6 0 구름많음
# A02 2022-01-08 00:00 -6 5 구름많음
# A02 2022-01-08 12:00 -6 5 구름많음
# A02 2022-01-09 00:00 -2 4 흐림
# A02 2022-01-09 12:00 -2 4 구름많음
# A02 2022-01-10 00:00 -5 3 구름많음
# A02 2022-01-10 12:00 -5 3 구름많음
# A02 2022-01-11 00:00 -8 -1 맑음
# A02 2022-01-11 12:00 -8 -1 맑음
# A02 2022-01-12 00:00 -7 3 맑음
# A02 2022-01-12 12:00 -7 3 맑음
# A01 2022-01-13 00:00 -4 3 구름많음
# A01 2022-01-14 00:00 -6 1 맑음
# A01 2022-01-15 00:00 -7 1 구름많음
# A02 2022-01-12 00:00 -9 2 맑음
# A02 2022-01-12 12:00 -9 2 맑음
# A01 2022-01-13 00:00 -4 4 구름많음
# A01 2022-01-14 00:00 -7 0 맑음
# A01 2022-01-15 00:00 -8 1 구름많음
# A02 2022-01-08 00:00 -7 5 구름많음
# A02 2022-01-08 12:00 -7 5 구름많음
# A02 2022-01-09 00:00 -3 4 흐림
# A02 2022-01-09 12:00 -3 4 구름많음
# A02 2022-01-10 00:00 -6 3 구름많음
# A02 2022-01-10 12:00 -6 3 구름많음
# A02 2022-01-11 00:00 -9 -1 맑음
# A02 2022-01-11 12:00 -9 -1 맑음
# A02 2022-01-12 00:00 -10 3 맑음
# A02 2022-01-12 12:00 -10 3 맑음
# A01 2022-01-13 00:00 -5 3 구름많음
# A01 2022-01-14 00:00 -8 0 맑음
# A01 2022-01-15 00:00 -10 1 구름많음
# A02 2022-01-08 00:00 -7 4 구름많음
# A02 2022-01-08 12:00 -7 4 구름많음
# A02 2022-01-09 00:00 -3 4 흐림
# A02 2022-01-09 12:00 -3 4 구름많음
# A02 2022-01-10 00:00 -6 2 구름많음
# A02 2022-01-10 12:00 -6 2 구름많음
# A02 2022-01-11 00:00 -10 -3 맑음
# A02 2022-01-11 12:00 -10 -3 맑음
# A02 2022-01-12 00:00 -10 1 맑음
# A02 2022-01-12 12:00 -10 1 맑음
# A01 2022-01-13 00:00 -6 3 구름많음
# A01 2022-01-14 00:00 -9 -2 맑음
# A01 2022-01-15 00:00 -10 -2 구름많음
# A02 2022-01-08 00:00 -8 4 구름많음
# A02 2022-01-08 12:00 -8 4 구름많음
# A02 2022-01-09 00:00 -3 4 흐림
# A02 2022-01-09 12:00 -3 4 구름많음
# A02 2022-01-10 00:00 -5 3 구름많음
# A02 2022-01-10 12:00 -5 3 구름많음
# A02 2022-01-11 00:00 -8 -1 맑음
# A02 2022-01-11 12:00 -8 -1 맑음
# A02 2022-01-12 00:00 -10 1 맑음
# A02 2022-01-12 12:00 -10 1 맑음
# A01 2022-01-13 00:00 -5 3 구름많음
# A01 2022-01-14 00:00 -9 -1 맑음
# A01 2022-01-15 00:00 -10 -1 구름많음

# %%
df
# Out:
#     mo_de             tm_ef  tmn tmx    wf
# 0     A01  2022-01-08 00:00   -4   4  구름많음
# 1     A01  2022-01-08 12:00   -4   4  구름많음
# 2     A01  2022-01-09 00:00   -1   4    흐림
# 3     A01  2022-01-09 12:00   -1   4  구름많음
# 4     A01  2022-01-10 00:00   -4   3  구름많음
# ..    ...               ...  ...  ..   ...
# 450   A01  2022-01-12 00:00  -10   1    맑음
# 451   A01  2022-01-12 12:00  -10   1    맑음
# 452   A01  2022-01-13 00:00   -5   3  구름많음
# 453   A01  2022-01-14 00:00   -9  -1    맑음
# 454   A01  2022-01-15 00:00  -10  -1  구름많음
#
# [455 rows x 5 columns]

# %% [markdown]
# # ch2.6 데이터 저장하기

# %% [markdown]
# ## ch2.6.1 CSV 파일로 저장하기

# %%
df.to_csv('weahter.csv', encoding='utf-8-sig')
